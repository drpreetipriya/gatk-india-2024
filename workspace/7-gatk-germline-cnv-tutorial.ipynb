# %% [markdown]
# # GATK Germline Copy Number Variation Tutorial <a class="tocSkip">

# %% [markdown]
# **March 2023**
#
# <img src="https://storage.googleapis.com/broad-dsde-methods-gatk-workshop-public/images/germline-cnv-tutorial/gatk-gcnv-pipeline-overview.png" alt="drawing" width="100%" align="center"/>
#
#
# The tutorial outlines steps in detecting germline copy number variants using GATK-gCNVs and illustrates two workflow modes: **cohort mode** and the **case mode**. The cohort mode simultaneously generates a cohort model and calls CNVs for the cohort samples. The case mode analyzes a single sample against an already constructed cohort model. The same workflow steps apply to both targeted exome and whole genome sequencing (WGS) data. The workflow is able to call both rare and common events and intelligently handles allosomal ploidies, i.e. cohorts of mixed male and female samples.
#
# For the cohort mode, the general recommendation is at least a hundred samples to start. Researchers should expect to tune workflow parameters from the provided defaults. In particular, GermlineCNVCaller's default inference parameters are conservatively set for efficient run times.
#
# The figure above diagrams the workflow tools. **Section 1** sets up the Notebook environment and downloads the data and resource files needed to complete this tutorial. **Section 2** creates an intervals list and counts read alignments overlapping the intervals. **Section 3** shows optional but recommended cohort mode steps to annotate intervals with covariates for use in filtering intervals as well as for use in explicit modeling. The section also removes outlier counts intervals. **Section 4** generates global baseline observations for the data and models and calls the ploidy of each contig (ploidy means the overall baseline copy number of the contig). **Section 5** is at the heart of the workflow and models per-interval copy number. Because of the high intensity of compute model fitting requires, the section shows how to analyze data in parts. Finally, **Section 6** calls per-sample copy number events per interval and per segment. Results are in VCF format.
#
# ➤ This guided Notebook demo is largely based on [Tutorial #11682](https://gatk.broadinstitute.org/hc/en-us/articles/360035531152--How-to-Call-common-and-rare-germline-copy-number-variants)
# ➤ A highly recommended [paper](https://www.nature.com/articles/s41588-023-01449-0) detailing the methods was published in _Nature Genetics_ in 2023.
# ➤ For pipelined workflows, see the WDL scripts in this Terra workspace.
# ➤ This workflow is **not** appropriate for bulk tumor samples, as it infers absolute copy numbers. For somatic copy number alteration calling, see [Tutorial #11682](https://gatk.zendesk.com/hc/en-us/articles/360035531092).
#
# _This tutorial was last tested with the GATK v4.2.4.0 and IGV v2.8.0._
#  See [GATK Tool Documentation](https://gatk.broadinstitute.org/hc/en-us/articles/360037224712) for further information on the tools we use below.

# %% [markdown]
# # Set up your Notebook
#
#
# ## Set cloud environment values
# If you are opening a notebook for the first time today and you didn't adjust any runtime values, now's the time to edit them. Click on the gear icon in the upper right to edit your Notebook Runtime. Set the values as specified below:
#
# | Option | Value |
# | ------ | ------ |
# | Environment | [Custom](https://github.com/broadinstitute/gatk-workshop-terra-jupyter-image/wiki/Using-the-gatk%E2%80%90workshop%E2%80%90terra%E2%80%90jupyter%E2%80%90image-in-the-Terra-Jupyter-environment#6-type-the-command-setup_gatk_env-in-the-terminal-and-hit-enter) |
# | Profile | Custom |
# | CPU | 4 |
# | Disk size | 100 GB |
# | Memory | 15 GB |
#
# **Please Note:** This notebook currently requires the use of a custom environment, as described [here](https://github.com/broadinstitute/gatk-workshop-terra-jupyter-image/wiki/Using-the-gatk%E2%80%90workshop%E2%80%90terra%E2%80%90jupyter%E2%80%90image-in-the-Terra-Jupyter-environment#6-type-the-command-setup_gatk_env-in-the-terminal-and-hit-enter).
#
# Click the "create"/"Update" button when you are done, and Terra will begin to create a new runtime with your settings. When it is finished, it will pop up asking you to apply the new settings. In the meantime, you can continue with the setup instructions below.

# %% [markdown]
# ## Setup the GATK conda environment
#
# Run the following commands in the Terra terminal (available from the right panel):
#
# ```
# setup_gatk_env
# ```
#
# When you are done, you should close this notebook and reopen.

# %% [markdown]
# ## Check kernel type selected in the Jupyter notebook
# For this particular notebook, we will be using a specialized kernel that we've added to our **Kernel** menu by following the previous two steps for creating the custom envrionemnt. If you've successfully done this, you should be able to select a kernel called `Python [conda env:gatkconda]`under the **Kernel** > **Change Kernel** menu.

# %% [markdown]
# ## Set up your files
# Your notebook has a temporary folder that exists so long as your cluster is running. To see what files are in your notebook environment at any time, you can click on the Jupyter logo in the upper left corner.
#
# For this tutorial, we need to copy some files from this temporary folder to and from our workspace bucket. Run the two commands below to set up the workspace bucket variable and the file paths inside your notebook.
#
# <font color = "green"> **Tool Tip:** To run a cell in a notebook, press `SHIFT + ENTER`</font>

# %%
# Set your workspace bucket variable for this notebook.
import os

# Get the workspace bucket from Terra Bio
os.environ['WORKSPACE_BUCKET'] = "gs://fc-b426f92d-adf2-45bc-a714-69ee3db2ba38"

WORKSPACE_BUCKET = os.environ['WORKSPACE_BUCKET']
WORKSHOP_BUCKET = 'gs://broad-dsde-methods-gatk-workshop-public'
REFERENCE_BUCKET = 'gs://genomics-public-data/resources/broad/hg38/v0'
WORKSPACE_LOCAL = '/home/jupyter/notebooks/germline-cnv'

# %%
# Create sandbox and file directories
! mkdir -p $WORKSPACE_LOCAL/sandbox/
! mkdir -p $WORKSPACE_LOCAL/ref/
! mkdir -p $WORKSPACE_LOCAL/data/

# Removes any old symbolic linked sandbox directory and adds a new link, in case you've run this before
! rm -rf sandbox
! ln -s $WORKSPACE_LOCAL/sandbox sandbox

# %% [markdown]
# ## Check data permissions
# For this tutorial, we have hosted the starting files in a public Google bucket. We will first check that the data is available to your user account, and if it is not, we simply need to install Google Cloud Storage.

# %%
# Check if data is accessible. The command should list several gs:// URLs.
! gsutil ls $WORKSHOP_BUCKET/germline-cnv
# Out:
# gs://broad-dsde-methods-gatk-workshop-public/germline-cnv/
# gs://broad-dsde-methods-gatk-workshop-public/germline-cnv/tutorial_11684.tar.gz

# %%
# If you do not see gs:// URLs listed above, run this cell to install Google Cloud Storage. 
# Afterwards, restart the kernel with Kernel > Restart.
#! pip install google-cloud-storage

# %% [markdown]
# ## Download data to local disk

# %% [markdown]
# The tutorial provides example small WGS data sourced from the _1000 Genomes Project_. Cohort mode illustrations use 24 samples, while case mode illustrations analyze one sample against a cohort model made from the remaining 23 samples. The tutorial uses a fraction of the workflow's recommended hundred samples for ease of illustration. Furthermore, commands in each step use one of three differently sized intervals lists for efficiency. Coverage data are from the entirety of chr20, chrX and chrY. So although a step may analyze a subset of regions, it is possible to instead analyze all three contigs in case or cohort modes.
#
# Download tutorial_11684.tar.gz either from the Workshop Google bucket. The bundle includes data for [Notebook #11685](https://gatk.zendesk.com/hc/en-us/articles/360035890031) and [Notebook #11686](https://gatk.zendesk.com/hc/en-us/articles/360035889891). The tutorial also requires the GRCh38 reference FASTA, dictionary and index. These are available from the GATK Resource Bundle. The example data is from the [1000 Genomes project](http://www.internationalgenome.org/) Phase 3 aligned to GRCh38.

# %%
! gsutil cp $WORKSHOP_BUCKET/germline-cnv/tutorial_11684.tar.gz /home/jupyter/notebooks/germline-cnv/data/
# Out:
# Copying gs://broad-dsde-methods-gatk-workshop-public/germline-cnv/tutorial_11684.tar.gz...
# ==> NOTE: You are downloading one or more large file(s), which would
# run significantly faster if you enabled sliced object downloads. This
# feature is enabled by default but requires that compiled crcmod be
# installed (see "gsutil help crcmod").
#
# | [1 files][543.0 MiB/543.0 MiB]   13.5 MiB/s
# Operation completed over 1 objects/543.0 MiB.

# %%
! tar -xvf $WORKSPACE_LOCAL/data/tutorial_11684.tar.gz -C $WORKSPACE_LOCAL/data > /dev/null 2>&1

# %%
# let's make a shortcut variable
TUTORIAL_DATA_PATH = '/home/jupyter/notebooks/germline-cnv/data/Tutorial11684'

# %% [markdown]
# ---
#
# # Collect raw counts data with _PreprocessIntervals_ and _CollectReadCounts_
# PreprocessIntervals pads exome targets and bins WGS intervals. Binning refers to creating equally sized intervals across the reference. For example, 1000 base binning would define chr1:1-1000 as the first bin. Because counts of reads on reference N bases are not meaningful, the tool automatically excludes bins with all Ns. For GRCh38 chr1, non-N sequences start at base 10,001, so the first few bin become:

# %% [markdown]
# ## For WGS data, bin entirety of reference, e.g. with 1000 base intervals.
# (We skip this step in this tutorial, but the command-line is shown below for your reference)

# %%
#  ! gatk PreprocessIntervals \
#         -R $REFERENCE_BUCKET/Homo_sapiens_assembly38.fasta \
#         --padding 0 \
#         -imr OVERLAPPING_ONLY \
#         -O $WORKSPACE_LOCAL/sandbox/grch38.preprocessed.interval_list

# %% [markdown]
# This produces a Picard-style intervals list of 1000 base bins.

# %% [markdown]
# ## For exome data, pad target regions, e.g. with 250 bases.
# (We skip this step in this tutorial since the data is WGS, but the command-line is shown below for your reference)

# %%
# ! gatk PreprocessIntervals \
#         -R $REFERENCE_BUCKET/Homo_sapiens_assembly38.fasta \
#         -L $TUTORIAL_DATA_PATH/targets.interval_list \
#         --bin-length 0 \
#         -imr OVERLAPPING_ONLY \
#         -O $WORKSPACE_LOCAL/sandbox/targets.preprocessed.interval_list

# %% [markdown]
# ## For the tutorial, we only bin two contigs
# Lets subset the reference to just chr20 and chrY.

# %%
! gatk PreprocessIntervals \
        -R $REFERENCE_BUCKET/Homo_sapiens_assembly38.fasta \
        --bin-length 1000 \
        --padding 0 \
        -L chr20 -L chrY \
        -imr OVERLAPPING_ONLY \
        -O $WORKSPACE_LOCAL/sandbox/chr20Y.interval_list
# Out:
# Using GATK jar /gatk/gatk-package-4.5.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /gatk/gatk-package-4.5.0.0-local.jar PreprocessIntervals -R gs://genomics-public-data/resources/broad/hg38/v0/Homo_sapiens_assembly38.fasta --bin-length 1000 --padding 0 -L chr20 -L chrY -imr OVERLAPPING_ONLY -O /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list
# 16:38:07.812 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/gatk/gatk-package-4.5.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 16:38:07.993 INFO  PreprocessIntervals - ------------------------------------------------------------
# 16:38:07.998 INFO  PreprocessIntervals - The Genome Analysis Toolkit (GATK) v4.5.0.0
# 16:38:07.998 INFO  PreprocessIntervals - For support and documentation go to https://software.broadinstitute.org/gatk/
# 16:38:07.998 INFO  PreprocessIntervals - Executing as root@6fffd5f5c26a on Linux v6.5.11-linuxkit amd64
# 16:38:07.998 INFO  PreprocessIntervals - Java runtime: OpenJDK 64-Bit Server VM v17.0.9+9-Ubuntu-122.04
# 16:38:07.998 INFO  PreprocessIntervals - Start Date/Time: January 19, 2024 at 4:38:07 PM GMT
# 16:38:07.998 INFO  PreprocessIntervals - ------------------------------------------------------------
# 16:38:07.998 INFO  PreprocessIntervals - ------------------------------------------------------------
# 16:38:08.001 INFO  PreprocessIntervals - HTSJDK Version: 4.1.0
# 16:38:08.001 INFO  PreprocessIntervals - Picard Version: 3.1.1
# 16:38:08.001 INFO  PreprocessIntervals - Built for Spark Version: 3.5.0
# 16:38:08.002 INFO  PreprocessIntervals - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 16:38:08.002 INFO  PreprocessIntervals - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 16:38:08.002 INFO  PreprocessIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 16:38:08.003 INFO  PreprocessIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 16:38:08.003 INFO  PreprocessIntervals - Deflater: IntelDeflater
# 16:38:08.003 INFO  PreprocessIntervals - Inflater: IntelInflater
# 16:38:08.003 INFO  PreprocessIntervals - GCS max retries/reopens: 20
# 16:38:08.003 INFO  PreprocessIntervals - Requester pays: disabled
# 16:38:08.004 INFO  PreprocessIntervals - Initializing engine
# 16:38:16.583 INFO  IntervalArgumentCollection - Processing 121671582 bp from intervals
# 16:38:16.588 INFO  PreprocessIntervals - Done initializing engine
# 16:38:16.591 INFO  ProgressMeter - Starting traversal
# 16:38:16.593 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Records Processed   Records/Minute
# 16:38:16.595 INFO  ProgressMeter -             unmapped              0.0                     0              NaN
# 16:38:16.595 INFO  ProgressMeter - Traversal complete. Processed 0 total records in 0.0 minutes.
# 16:38:16.595 INFO  PreprocessIntervals - Padding intervals...
# 16:38:16.598 INFO  PreprocessIntervals - Generating bins...
# 16:38:16.620 INFO  PreprocessIntervals - Filtering bins containing only Ns...
# 16:54:11.266 INFO  PreprocessIntervals - Writing bins to /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list...
# 16:54:11.439 INFO  PreprocessIntervals - PreprocessIntervals complete.
# 16:54:11.440 INFO  PreprocessIntervals - Shutting down engine
# [January 19, 2024 at 4:54:11 PM GMT] org.broadinstitute.hellbender.tools.copynumber.PreprocessIntervals done. Elapsed time: 16.06 minutes.
# Runtime.totalMemory()=143654912

# %%
# let us take a look
! grep -v '^@' $WORKSPACE_LOCAL/sandbox/chr20Y.interval_list | head -n 10
# Out:
# chr20	60001	61000	+	.
# chr20	61001	62000	+	.
# chr20	62001	63000	+	.
# chr20	63001	64000	+	.
# chr20	64001	65000	+	.
# chr20	65001	66000	+	.
# chr20	66001	67000	+	.
# chr20	67001	68000	+	.
# chr20	68001	69000	+	.
# chr20	69001	70000	+	.

# %% [markdown]
# ### Comments on select parameters of _PreprocessIntervals_
#
# - For WGS, the default 1000 `--bin-length` is the recommended starting point for typical 30x data. Be sure to set `--padding 0` to disable padding outside of given genomic regions. Bin size should correlate with depth of coverage, e.g. lower coverage data should use larger bin size while higher coverage data can support smaller bin size. The size of the bin defines the resolution of CNV calls. The factors to consider in sizing include how noisy the data is, average coverage depth and how even coverage is across the reference.
#
# - For targeted exomes, provide the exome capture kit's target intervals with `-L`, set `--bin-length 0` to disable binning and pad the intervals with `--padding 250` or other desired length.
#
# - Provide intervals to exclude from analysis with `--exclude-intervals` or `-XL`, e.g. centromeric regions. Consider using this option especially if data is aligned to a reference other than GRCh38. The workflow enables excluding regions later again using `-XL`. A frugal strategy is to collect read counts using the entirety of intervals and then to exclude undesirable regions later at the _FilterIntervals_ step (section 3), the _DetermineGermlineContigPloidy_ step (section 4), at the _GermlineCNVCaller_ step (section 6) and/or post-calling.

# %% [markdown]
# ## Count reads per bin using _CollectReadCounts_
# _CollectReadCounts_ tabulates the raw integer counts of reads overlapping an interval. The tutorial has already collected read counts ahead of time for the three contigs: chr20 and chrY. Here, we collect read counts on small data.

# %%
! gatk CollectReadCounts \
        -L $TUTORIAL_DATA_PATH/chr20sub.interval_list \
        -R $REFERENCE_BUCKET/Homo_sapiens_assembly38.fasta \
        -imr OVERLAPPING_ONLY \
        -I $TUTORIAL_DATA_PATH/NA19017.chr20sub.bam \
        --format TSV \
        -O $WORKSPACE_LOCAL/sandbox/NA19017.tsv
# Out:
# Using GATK jar /gatk/gatk-package-4.5.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /gatk/gatk-package-4.5.0.0-local.jar CollectReadCounts -L /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/chr20sub.interval_list -R gs://genomics-public-data/resources/broad/hg38/v0/Homo_sapiens_assembly38.fasta -imr OVERLAPPING_ONLY -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/NA19017.chr20sub.bam --format TSV -O /home/jupyter/notebooks/germline-cnv/sandbox/NA19017.tsv
# 00:51:42.065 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/gatk/gatk-package-4.5.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 00:51:42.487 INFO  CollectReadCounts - ------------------------------------------------------------
# 00:51:42.490 INFO  CollectReadCounts - The Genome Analysis Toolkit (GATK) v4.5.0.0
# 00:51:42.490 INFO  CollectReadCounts - For support and documentation go to https://software.broadinstitute.org/gatk/
# 00:51:42.490 INFO  CollectReadCounts - Executing as root@6fffd5f5c26a on Linux v6.5.11-linuxkit amd64
# 00:51:42.490 INFO  CollectReadCounts - Java runtime: OpenJDK 64-Bit Server VM v17.0.9+9-Ubuntu-122.04
# 00:51:42.490 INFO  CollectReadCounts - Start Date/Time: January 20, 2024 at 12:51:42 AM GMT
# 00:51:42.490 INFO  CollectReadCounts - ------------------------------------------------------------
# 00:51:42.491 INFO  CollectReadCounts - ------------------------------------------------------------
# 00:51:42.493 INFO  CollectReadCounts - HTSJDK Version: 4.1.0
# 00:51:42.493 INFO  CollectReadCounts - Picard Version: 3.1.1
# 00:51:42.493 INFO  CollectReadCounts - Built for Spark Version: 3.5.0
# 00:51:42.494 INFO  CollectReadCounts - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 00:51:42.495 INFO  CollectReadCounts - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 00:51:42.495 INFO  CollectReadCounts - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 00:51:42.495 INFO  CollectReadCounts - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 00:51:42.495 INFO  CollectReadCounts - Deflater: IntelDeflater
# 00:51:42.495 INFO  CollectReadCounts - Inflater: IntelInflater
# 00:51:42.495 INFO  CollectReadCounts - GCS max retries/reopens: 20
# 00:51:42.495 INFO  CollectReadCounts - Requester pays: disabled
# 00:51:42.496 INFO  CollectReadCounts - Initializing engine
# 00:52:01.706 INFO  FeatureManager - Using codec IntervalListCodec to read file file:///home/jupyter/notebooks/germline-cnv/data/Tutorial11684/chr20sub.interval_list
# 00:52:02.106 INFO  IntervalArgumentCollection - Processing 15103000 bp from intervals
# 00:52:02.144 INFO  CollectReadCounts - Done initializing engine
# 00:52:02.168 INFO  CollectReadCounts - Collecting read counts...
# 00:52:02.168 INFO  ProgressMeter - Starting traversal
# 00:52:02.170 INFO  ProgressMeter -        Current Locus  Elapsed Minutes       Reads Processed     Reads/Minute
# 00:52:10.066 INFO  CollectReadCounts - 0 read(s) filtered by: WellformedReadFilter
# 110022 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 45195 read(s) filtered by: NotDuplicateReadFilter
# 158151 read(s) filtered by: MappingQualityReadFilter
# 313368 total reads filtered out of 3566880 reads processed
# 00:52:10.072 INFO  ProgressMeter -       chr20:64332513              0.1               3253512       24716475.1
# 00:52:10.072 INFO  ProgressMeter - Traversal complete. Processed 3253512 total reads in 0.1 minutes.
# 00:52:10.072 INFO  CollectReadCounts - Writing read counts to /home/jupyter/notebooks/germline-cnv/sandbox/NA19017.tsv...
# 00:52:10.287 INFO  CollectReadCounts - CollectReadCounts complete.
# 00:52:10.288 INFO  CollectReadCounts - Shutting down engine
# [January 20, 2024 at 12:52:10 AM GMT] org.broadinstitute.hellbender.tools.copynumber.CollectReadCounts done. Elapsed time: 0.47 minutes.
# Runtime.totalMemory()=157286400

# %% [markdown]
# This generates a TSV format table of read counts. Let's take a look. After the SAM format header section, denoted by lines starting with `@`, the body of the data has a column header line followed by read counts for every interval:

# %%
! grep -v '^@' $WORKSPACE_LOCAL/sandbox/NA19017.tsv | head -n 10
# Out:
# CONTIG	START	END	COUNT
# chr20	60001	61000	253
# chr20	61001	62000	560
# chr20	62001	63000	465
# chr20	63001	64000	108
# chr20	64001	65000	261
# chr20	65001	66000	370
# chr20	66001	67000	308
# chr20	67001	68000	286
# chr20	68001	69000	247

# %% [markdown]
# ### Comments on select parameters of _CollectReadCounts_
#
# - The tutorial generates text-based TSV (tab-separated-value) format data instead of the default HDF5 format by adding `--format TSV` to the command. Omit this option to generate the default HDF5 format. Downstream tools process HDF5 format more efficiently.
#
# - Here and elsewhere in the workflow, set `--interval-merging-rule` (`-imr`) to `OVERLAPPING_ONLY`, to prevent the tool from merging abutting intervals.
#
# - The tool employs a number of engine-level read filters. Of note are _NotDuplicateReadFilter_ and _MappingQualityReadFilter_. This means the tool excludes reads marked as duplicate and excludes reads with mapping quality less than `10`. Change the mapping quality threshold with the `--minimum-mapping-quality` option.

# %% [markdown]
# # Annotate intervals with features using _AnnotateIntervals_ and subset regions of interest using _FilterIntervals_
#
# The steps in this section pertain to the **cohort mode**.
#
# Researchers may desire to subset the intervals that _GermlineCNVCaller_ will analyze, either to exclude potentially problematic regions or to retain only regions of interest. For example one may wish to exclude regions where all samples in a large cohort have copy number zero, or regions around segmental duplications (low-copy repeats) that often harbor common CNVs (e.g. in case the researcher is primarily interested in _de novo_ CNVs). Filtering intervals can be especially impactful for analyses that utilize references other than GRCh38 or that are based on sequencing technologies affected by sequence context, e.g. targeted exomes. The tutorial data is WGS data aligned to GRCh38, and the gCNV workflow can process the entirety of the data, without the need for any interval filtering.
#
# Towards deciding which regions to exclude, _AnnotateIntervals_ labels the given intervals with GC content and additionally with mappability and segmental duplication content if given the respective optional resource files. _FilterIntervals_ then subsets the intervals list based on the annotations and other tunable thresholds. Later, _GermlineCNVCaller_ also takes in the annotated intervals to use as covariates towards analysis.
#
# Explicit GC-correction, although optional, is recommended. The default v4.1.0.0 `cnv_germline_cohort_workflow.wdl` pipeline workflow omits explicit gc-correction and we activate it in the pipeline by setting `do_explicit_gc_correction":"True"`. The tutorial illustrates the optional _AnnotateIntervals_ step by performing the recommended explicit GC-content-based filtering.

# %% [markdown]
# ## _AnnotateIntervals_ with GC content

# %%
! gatk AnnotateIntervals \
        -L $WORKSPACE_LOCAL/sandbox/chr20Y.interval_list \
        -R $REFERENCE_BUCKET/Homo_sapiens_assembly38.fasta \
        -imr OVERLAPPING_ONLY \
        -O $WORKSPACE_LOCAL/sandbox/chr20Y.annotated.tsv
# Out:
# Using GATK jar /gatk/gatk-package-4.5.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /gatk/gatk-package-4.5.0.0-local.jar AnnotateIntervals -L /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list -R gs://genomics-public-data/resources/broad/hg38/v0/Homo_sapiens_assembly38.fasta -imr OVERLAPPING_ONLY -O /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.annotated.tsv
# 00:52:23.017 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/gatk/gatk-package-4.5.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 00:52:23.194 INFO  AnnotateIntervals - ------------------------------------------------------------
# 00:52:23.198 INFO  AnnotateIntervals - The Genome Analysis Toolkit (GATK) v4.5.0.0
# 00:52:23.198 INFO  AnnotateIntervals - For support and documentation go to https://software.broadinstitute.org/gatk/
# 00:52:23.199 INFO  AnnotateIntervals - Executing as root@6fffd5f5c26a on Linux v6.5.11-linuxkit amd64
# 00:52:23.199 INFO  AnnotateIntervals - Java runtime: OpenJDK 64-Bit Server VM v17.0.9+9-Ubuntu-122.04
# 00:52:23.199 INFO  AnnotateIntervals - Start Date/Time: January 20, 2024 at 12:52:22 AM GMT
# 00:52:23.200 INFO  AnnotateIntervals - ------------------------------------------------------------
# 00:52:23.200 INFO  AnnotateIntervals - ------------------------------------------------------------
# 00:52:23.203 INFO  AnnotateIntervals - HTSJDK Version: 4.1.0
# 00:52:23.203 INFO  AnnotateIntervals - Picard Version: 3.1.1
# 00:52:23.203 INFO  AnnotateIntervals - Built for Spark Version: 3.5.0
# 00:52:23.205 INFO  AnnotateIntervals - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 00:52:23.205 INFO  AnnotateIntervals - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 00:52:23.205 INFO  AnnotateIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 00:52:23.205 INFO  AnnotateIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 00:52:23.205 INFO  AnnotateIntervals - Deflater: IntelDeflater
# 00:52:23.205 INFO  AnnotateIntervals - Inflater: IntelInflater
# 00:52:23.206 INFO  AnnotateIntervals - GCS max retries/reopens: 20
# 00:52:23.206 INFO  AnnotateIntervals - Requester pays: disabled
# 00:52:23.207 INFO  AnnotateIntervals - Initializing engine
# 00:52:34.055 INFO  FeatureManager - Using codec IntervalListCodec to read file file:///home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list
# 00:52:35.075 INFO  IntervalArgumentCollection - Processing 87641000 bp from intervals
# 00:52:35.112 INFO  AnnotateIntervals - Done initializing engine
# 00:52:35.114 INFO  AnnotateIntervals - Loading intervals for annotation...
# 00:52:35.114 INFO  AnnotateIntervals - Loading resources for annotation...
# 00:52:45.403 INFO  AnnotateIntervals - Adding GC-content annotator...
# 00:52:45.406 INFO  AnnotateIntervals - Annotating intervals...
# 00:52:45.407 INFO  ProgressMeter - Starting traversal
# 00:52:45.417 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Records Processed   Records/Minute
# 00:53:01.755 INFO  ProgressMeter -        chr20:2059001              0.3                  2000           7352.5
# 00:53:17.881 INFO  ProgressMeter -        chr20:4059001              0.5                  4000           7393.5
# 00:53:36.241 INFO  ProgressMeter -        chr20:6059001              0.8                  6000           7084.1
# 00:53:56.108 INFO  ProgressMeter -        chr20:8059001              1.2                  8000           6790.5
# 00:54:12.312 INFO  ProgressMeter -       chr20:10059001              1.4                 10000           6905.2
# 00:54:28.484 INFO  ProgressMeter -       chr20:12059001              1.7                 12000           6985.9
# 00:54:44.546 INFO  ProgressMeter -       chr20:14059001              2.0                 14000           7051.3
# 00:55:00.415 INFO  ProgressMeter -       chr20:16059001              2.2                 16000           7111.3
# 00:55:16.349 INFO  ProgressMeter -       chr20:18059001              2.5                 18000           7155.6
# 00:55:32.364 INFO  ProgressMeter -       chr20:20059001              2.8                 20000           7188.0
# 00:55:48.212 INFO  ProgressMeter -       chr20:22059001              3.0                 22000           7221.3
# 00:56:04.020 INFO  ProgressMeter -       chr20:24059001              3.3                 24000           7250.7
# 00:56:19.883 INFO  ProgressMeter -       chr20:26059001              3.6                 26000           7273.9
# 00:56:35.169 INFO  ProgressMeter -       chr20:27113001              3.8                 27000           7051.1
# 00:56:50.157 INFO  ProgressMeter -       chr20:29137001              4.1                 29000           7109.6
# 00:57:05.745 INFO  ProgressMeter -       chr20:31364001              4.3                 31000           7144.9
# 00:57:21.659 INFO  ProgressMeter -       chr20:33364001              4.6                 33000           7167.8
# 00:57:37.486 INFO  ProgressMeter -       chr20:35364001              4.9                 35000           7190.1
# 00:57:53.214 INFO  ProgressMeter -       chr20:37364001              5.1                 37000           7212.6
# 00:58:08.998 INFO  ProgressMeter -       chr20:39364001              5.4                 39000           7231.7
# 00:58:24.939 INFO  ProgressMeter -       chr20:41364001              5.7                 41000           7245.6
# 00:58:41.706 INFO  ProgressMeter -       chr20:43364001              5.9                 43000           7241.4
# 00:58:57.642 INFO  ProgressMeter -       chr20:45364001              6.2                 45000           7253.7
# 00:59:13.598 INFO  ProgressMeter -       chr20:47364001              6.5                 47000           7264.7
# 00:59:29.754 INFO  ProgressMeter -       chr20:49364001              6.7                 49000           7271.2
# 00:59:45.739 INFO  ProgressMeter -       chr20:51364001              7.0                 51000           7280.2
# 01:00:01.795 INFO  ProgressMeter -       chr20:53364001              7.3                 53000           7287.3
# 01:00:17.749 INFO  ProgressMeter -       chr20:55364001              7.5                 55000           7295.6
# 01:00:33.741 INFO  ProgressMeter -       chr20:57364001              7.8                 57000           7302.7
# 01:00:49.714 INFO  ProgressMeter -       chr20:59364001              8.1                 59000           7309.6
# 01:01:05.529 INFO  ProgressMeter -       chr20:61364001              8.3                 61000           7318.4
# 01:01:21.132 INFO  ProgressMeter -       chr20:63364001              8.6                 63000           7329.7
# 01:01:31.909 INFO  ProgressMeter -         chrY:2810001              8.8                 64000           7293.6
# 01:01:47.890 INFO  ProgressMeter -         chrY:4810001              9.0                 66000           7299.9
# 01:02:03.698 INFO  ProgressMeter -         chrY:6810001              9.3                 68000           7308.2
# 01:02:20.358 INFO  ProgressMeter -         chrY:8810001              9.6                 70000           7305.1
# 01:02:36.478 INFO  ProgressMeter -        chrY:11083001              9.9                 72000           7308.9
# 01:02:52.486 INFO  ProgressMeter -        chrY:13133001             10.1                 74000           7313.9
# 01:03:09.748 INFO  ProgressMeter -        chrY:15133001             10.4                 76000           7304.0
# 01:03:25.769 INFO  ProgressMeter -        chrY:17133001             10.7                 78000           7308.5
# 01:03:41.660 INFO  ProgressMeter -        chrY:19133001             10.9                 80000           7314.4
# 01:03:58.538 INFO  ProgressMeter -        chrY:21182001             11.2                 82000           7309.2
# 01:04:14.495 INFO  ProgressMeter -        chrY:23198001             11.5                 84000           7314.1
# 01:04:31.776 INFO  ProgressMeter -        chrY:25198001             11.8                 86000           7305.1
# 01:21:04.119 INFO  ProgressMeter -        chrY:26198001             28.3                 87641           3095.6
# 01:21:04.120 INFO  ProgressMeter - Traversal complete. Processed 87641 total records in 28.3 minutes.
# 01:21:04.120 INFO  AnnotateIntervals - Writing annotated intervals to /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.annotated.tsv...
# 01:21:04.757 INFO  AnnotateIntervals - AnnotateIntervals complete.
# 01:21:04.757 INFO  AnnotateIntervals - Shutting down engine
# [January 20, 2024 at 1:21:04 AM GMT] org.broadinstitute.hellbender.tools.copynumber.AnnotateIntervals done. Elapsed time: 28.70 minutes.
# Runtime.totalMemory()=169869312

# %% [markdown]
# This produces a four-column table where the fourth column gives the fraction of GC content. Let's take a look:

# %%
! grep -v '^@' $WORKSPACE_LOCAL/sandbox/chr20Y.annotated.tsv | head -n 10
# Out:
# CONTIG	START	END	GC_CONTENT
# chr20	60001	61000	0.470000
# chr20	61001	62000	0.473000
# chr20	62001	63000	0.482000
# chr20	63001	64000	0.469333
# chr20	64001	65000	0.476000
# chr20	65001	66000	0.477000
# chr20	66001	67000	0.483333
# chr20	67001	68000	0.399000
# chr20	68001	69000	0.293000

# %% [markdown]
# ### Comments on select parameters of _AnnotateIntervals_
#
# - The tool requires the `-R` reference and the `-L` intervals. The tool calculates GC-content for the intervals using the reference. Although optional for the tool, we recommend annotating mappability by providing a `--mappability-track` regions file in either .bed or .bed.gz format. Be sure to merge any overlapping intervals beforehand. The tutorial omits use of this resource.
#
# - GATK recommends use of the the single-read mappability track, as the multi-read track requires much longer times to process. For example, the Hoffman lab at the University of Toronto provides human and mouse mappability BED files for various kmer lengths at https://bismap.hoffmanlab.org. The accompanying publication is titled [Umap and Bismap: quantifying genome and methylome mappability](https://doi.org/10.1093/nar/gky677).
#
# - Optionally and additionally, annotate segmental duplication content by providing a `--segmental-duplication-track` regions file in either .bed or .bed.gz format.
#
# - Exclude undesirable intervals with the `-XL` parameter, e.g. intervals corresponding to centromeric regions.

# %% [markdown]
# ## _FilterIntervals_ based on GC-content and cohort extreme counts
#
# _FilterIntervals_ takes preprocessed intervals and either annotated intervals or read counts or both. It can also exclude intervals given with `-XL`. When given both types of data, the tool retains the intervals that intersect from filtering on each data type. The v4.1.0.0 `cnv_germline_cohort_workflow.wdl` pipeline script requires read counts files, and so by default the pipeline script always performs the _FilterIntervals_ step on read counts.

# %%
! gatk FilterIntervals \
        -L $WORKSPACE_LOCAL/sandbox/chr20Y.interval_list \
        --annotated-intervals $WORKSPACE_LOCAL/sandbox/chr20Y.annotated.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG00096.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG00268.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG00419.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG00759.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01051.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01112.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01500.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01565.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01583.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01595.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG01879.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG02568.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG02922.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG03006.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG03052.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG03642.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/HG03742.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        -imr OVERLAPPING_ONLY \
        -O $WORKSPACE_LOCAL/sandbox/chr20Y.cohort.gc.filtered.interval_list
# Out:
# Using GATK jar /gatk/gatk-package-4.5.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /gatk/gatk-package-4.5.0.0-local.jar FilterIntervals -L /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list --annotated-intervals /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.annotated.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00096.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00268.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00419.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00759.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01051.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01112.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01500.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01565.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01583.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01595.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01879.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG02568.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG02922.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03006.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03052.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03642.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03742.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18525.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18939.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19017.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19625.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19648.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20502.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20845.tsv -imr OVERLAPPING_ONLY -O /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.cohort.gc.filtered.interval_list
# 01:27:03.421 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/gatk/gatk-package-4.5.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 01:27:03.701 INFO  FilterIntervals - ------------------------------------------------------------
# 01:27:03.704 INFO  FilterIntervals - The Genome Analysis Toolkit (GATK) v4.5.0.0
# 01:27:03.704 INFO  FilterIntervals - For support and documentation go to https://software.broadinstitute.org/gatk/
# 01:27:03.704 INFO  FilterIntervals - Executing as root@6fffd5f5c26a on Linux v6.5.11-linuxkit amd64
# 01:27:03.704 INFO  FilterIntervals - Java runtime: OpenJDK 64-Bit Server VM v17.0.9+9-Ubuntu-122.04
# 01:27:03.705 INFO  FilterIntervals - Start Date/Time: January 20, 2024 at 1:27:03 AM GMT
# 01:27:03.705 INFO  FilterIntervals - ------------------------------------------------------------
# 01:27:03.705 INFO  FilterIntervals - ------------------------------------------------------------
# 01:27:03.707 INFO  FilterIntervals - HTSJDK Version: 4.1.0
# 01:27:03.707 INFO  FilterIntervals - Picard Version: 3.1.1
# 01:27:03.707 INFO  FilterIntervals - Built for Spark Version: 3.5.0
# 01:27:03.708 INFO  FilterIntervals - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 01:27:03.708 INFO  FilterIntervals - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 01:27:03.709 INFO  FilterIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 01:27:03.709 INFO  FilterIntervals - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 01:27:03.709 INFO  FilterIntervals - Deflater: IntelDeflater
# 01:27:03.709 INFO  FilterIntervals - Inflater: IntelInflater
# 01:27:03.709 INFO  FilterIntervals - GCS max retries/reopens: 20
# 01:27:03.709 INFO  FilterIntervals - Requester pays: disabled
# 01:27:03.710 INFO  FilterIntervals - Initializing engine
# 01:27:03.710 INFO  FilterIntervals - Done initializing engine
# 01:27:04.763 INFO  FeatureManager - Using codec IntervalListCodec to read file file:///home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.interval_list
# 01:27:05.513 INFO  IntervalArgumentCollection - Processing 87641000 bp from intervals
# 01:27:05.650 INFO  FilterIntervals - After interval resolution, 87641 intervals remain...
# 01:27:05.650 INFO  FilterIntervals - After interval intersection, 87641 intervals remain...
# 01:27:05.762 INFO  FilterIntervals - Applying annotation-based filters...
# 01:27:05.798 INFO  FilterIntervals - After applying GC-content filter (intervals with values outside of [0.1, 0.9] fail), 87636 / 87641 intervals remain...
# 01:27:05.799 INFO  FilterIntervals - Validating and aggregating input read-counts files...
# 01:27:05.828 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00096.tsv (1 / 24)
# 01:27:06.471 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00268.tsv (2 / 24)
# 01:27:06.802 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00419.tsv (3 / 24)
# 01:27:07.075 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG00759.tsv (4 / 24)
# 01:27:07.538 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01051.tsv (5 / 24)
# 01:27:07.922 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01112.tsv (6 / 24)
# 01:27:08.167 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01500.tsv (7 / 24)
# 01:27:08.412 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01565.tsv (8 / 24)
# 01:27:08.700 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01583.tsv (9 / 24)
# 01:27:09.162 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01595.tsv (10 / 24)
# 01:27:09.398 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG01879.tsv (11 / 24)
# 01:27:09.663 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG02568.tsv (12 / 24)
# 01:27:09.953 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG02922.tsv (13 / 24)
# 01:27:10.214 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03006.tsv (14 / 24)
# 01:27:10.462 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03052.tsv (15 / 24)
# 01:27:10.805 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03642.tsv (16 / 24)
# 01:27:11.083 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/HG03742.tsv (17 / 24)
# 01:27:11.320 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18525.tsv (18 / 24)
# 01:27:11.563 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18939.tsv (19 / 24)
# 01:27:11.817 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19017.tsv (20 / 24)
# 01:27:12.104 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19625.tsv (21 / 24)
# 01:27:12.369 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19648.tsv (22 / 24)
# 01:27:12.626 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20502.tsv (23 / 24)
# 01:27:12.902 INFO  FilterIntervals - Aggregating read-counts file /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20845.tsv (24 / 24)
# 01:27:13.189 INFO  FilterIntervals - Applying count-based filters...
# 01:27:13.278 INFO  FilterIntervals - After applying low-count filter (intervals with a count < 10 in > 50.0% of samples fail), 62824 / 87641 intervals remain...
# 01:27:13.450 INFO  FilterIntervals - After applying extreme-count filter (intervals with a count percentile outside of [1.0, 99.0] in > 90.0% of samples fail), 62398 / 87641 intervals remain...
# 01:27:13.487 INFO  FilterIntervals - 62398 / 87641 intervals passed all filters...
# 01:27:13.513 INFO  FilterIntervals - Writing filtered intervals to /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.cohort.gc.filtered.interval_list...
# 01:27:13.652 INFO  FilterIntervals - FilterIntervals complete.
# 01:27:13.653 INFO  FilterIntervals - Shutting down engine
# [January 20, 2024 at 1:27:13 AM GMT] org.broadinstitute.hellbender.tools.copynumber.FilterIntervals done. Elapsed time: 0.17 minutes.
# Runtime.totalMemory()=829423616

# %%
! grep -v '^@' $WORKSPACE_LOCAL/sandbox/chr20Y.interval_list | wc -l
! grep -v '^@' $WORKSPACE_LOCAL/sandbox/chr20Y.cohort.gc.filtered.interval_list | wc -l
# Out:
# 87641
# 62398

# %% [markdown]
# This produces a Picard-style intervals list containing a subset of the starting intervals (80,534 of 87,641).

# %% [markdown]
# ### Comments on select parameters of _FilterIntervals_
#
# - The tool requires the preprocessed intervals, provided with `-L`, from the previous section. Given annotated intervals with `--annotated-intervals`, the tool filters intervals on the given annotation(s).
#
# - GC-content thresholds are set by `--minimum-gc-content` and `--maximum-gc-content`, where defaults are `0.1` and `0.9`, respectively.
#
# - Mappability thresholds are set by `--minimum-mappability` and `--maximum-mappability`. Defaults are `0.9` and `1.0`, respectively.
#
# - Segmental duplication content thresholds are set by `--minimum-segmental-duplication-content` and `--maximum-segmental-duplication-content`. Defaults are 0.0 and 0.5, respectively.
#
# - Given read counts files, each with `-I` and in either HDF5 or TSV format, the tool filters intervals on low and extreme read counts with the following tunable thresholds.
#     - `--low-count-filter-count-threshold` default is `5`
#     - `--low-count-filter-percentage-of-samples` default is `90.0`
#     - `--extreme-count-filter-minimum-percentile` default is `1.0`
#     - `--extreme-count-filter-maximum-percentile` default is `99.0`
#     - `--extreme-count-filter-percentage-of-samples` default is `90.0`
# The read counts data must match each other in intervals. For the default parameters, the tool first filters intervals with a count less than `5` in greater than `90%` of the samples. The tool then filters the remaining intervals with a count percentile less than `1` or greater than `99` in a percentage of samples greater than `90%`. These parameters effectively exclude intervals where all samples have extreme outlier counts, e.g. are deleted.
#
# - To disable counts based filtering, omit the read counts or, e.g. when using the v4.1.0.0 _cnv_germline_cohort_workflow.wdl_ pipeline script, set the two percentage-of-samples parameters as follows.
#     - `--low-count-filter-percentage-of-samples 100`
#     - `--extreme-count-filter-percentage-of-samples 100`
#
# - Provide intervals to exclude from analysis with `--exclude-intervals` or `-XL`, e.g. centromeric regions. A frugal strategy is to collect read counts using the entirety of intervals and then to exclude undesirable regions later at the _FilterIntervals_ step (section 3), the _DetermineGermlineContigPloidy_ step (section 4), at the _GermlineCNVCaller_ step (section 6) and/or post-calling.

# %% [markdown]
# # Call autosomal and allosomal contig ploidy with _DetermineGermlineContigPloidy_
#
# _DetermineGermlineContigPloidy_ calls contig level ploidies (i.e. copy number) for both autosomal, e.g. human chr20, and allosomal contigs, e.g. human chrX. The tool determines baseline contig ploidies using sample coverages and contig ploidy priors that give the prior probabilities for each ploidy state for each contig. In this process, the tool generates global baseline coverage and noise data _GermlineCNVCaller_ will use in section 6.
#
# The tool determines baseline contig ploidies using the total read count per contig. Researchers should consider the impact of this for their data. For example, for the tutorial WGS data, the contribution of the PAR regions to total coverage counts on chrX is small and the tool correctly calls allosomal ploidies. However, consider blacklisting PAR regions for data where the contribution is disporportionate, e.g. targeted panels.

# %% [markdown]
# ## _DetermineGermlineContigPloidy_ in cohort mode
#
# The cohort mode requires a `--contig-ploidy-priors` table and produces a ploidy model. The ploidy prior table specifies the prior probability of various ploidy states is formatted as follows:

# %%
! cat $TUTORIAL_DATA_PATH/chr20XY_contig_ploidy_priors.tsv

# %% [markdown]
# According to this table, we put 98% prior probability to call chr20 as diploid (PLOIDY_PRIOR_2), 0% prior probability to call it homozygous deletion (would you be alive without chr20?), and a small probability 1% each for heterozygous deletion (PLOIDY_PRIOR_1) and trisomy (PLOIDY_PRIOR_3).

# %%
# --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 args only used 
# for tutorial to decreaase training time. Not recommeneded for use with full size data.

! gatk DetermineGermlineContigPloidy \
        -L $WORKSPACE_LOCAL/sandbox/chr20Y.cohort.gc.filtered.interval_list \
        --interval-merging-rule OVERLAPPING_ONLY \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-priors $TUTORIAL_DATA_PATH/chr20XY_contig_ploidy_priors.tsv \
        --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 \
        --output $WORKSPACE_LOCAL/sandbox \
        --output-prefix ploidy-cohort7 \
        --verbosity DEBUG
# Out:
# Using GATK jar /gatk/gatk-package-4.5.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /gatk/gatk-package-4.5.0.0-local.jar DetermineGermlineContigPloidy -L /home/jupyter/notebooks/germline-cnv/sandbox/chr20Y.cohort.gc.filtered.interval_list --interval-merging-rule OVERLAPPING_ONLY -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18525.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA18939.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19017.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19625.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA19648.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20502.tsv -I /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/cvg/NA20845.tsv --contig-ploidy-priors /home/jupyter/notebooks/germline-cnv/data/Tutorial11684/chr20XY_contig_ploidy_priors.tsv --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 --output /home/jupyter/notebooks/germline-cnv/sandbox --output-prefix ploidy-cohort7 --verbosity DEBUG
# 01:27:32.913 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/gatk/gatk-package-4.5.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 01:27:32.942 DEBUG NativeLibraryLoader - Extracting libgkl_compression.so to /tmp/libgkl_compression2714745363503502976.so
# 01:27:33.082 INFO  DetermineGermlineContigPloidy - ------------------------------------------------------------
# 01:27:33.086 INFO  DetermineGermlineContigPloidy - The Genome Analysis Toolkit (GATK) v4.5.0.0
# 01:27:33.086 INFO  DetermineGermlineContigPloidy - For support and documentation go to https://software.broadinstitute.org/gatk/
# 01:27:33.086 INFO  DetermineGermlineContigPloidy - Executing as root@6fffd5f5c26a on Linux v6.5.11-linuxkit amd64
# 01:27:33.086 INFO  DetermineGermlineContigPloidy - Java runtime: OpenJDK 64-Bit Server VM v17.0.9+9-Ubuntu-122.04
# 01:27:33.087 INFO  DetermineGermlineContigPloidy - Start Date/Time: January 20, 2024 at 1:27:32 AM GMT
# 01:27:33.087 INFO  DetermineGermlineContigPloidy - ------------------------------------------------------------
# 01:27:33.087 INFO  DetermineGermlineContigPloidy - ------------------------------------------------------------
# 01:27:33.089 INFO  DetermineGermlineContigPloidy - HTSJDK Version: 4.1.0
# 01:27:33.089 INFO  DetermineGermlineContigPloidy - Picard Version: 3.1.1
# 01:27:33.089 INFO  DetermineGermlineContigPloidy - Built for Spark Version: 3.5.0
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.BUFFER_SIZE : 131072
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.CREATE_INDEX : false
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.CREATE_MD5 : false
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.CUSTOM_READER_FACTORY :
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.DISABLE_SNAPPY_COMPRESSOR : false
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.EBI_REFERENCE_SERVICE_URL_MASK : https://www.ebi.ac.uk/ena/cram/md5/%s
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.NON_ZERO_BUFFER_SIZE : 131072
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.REFERENCE_FASTA : null
# 01:27:33.095 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.SAM_FLAG_FIELD_FORMAT : DECIMAL
# 01:27:33.096 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 01:27:33.096 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 01:27:33.096 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 01:27:33.096 INFO  DetermineGermlineContigPloidy - HTSJDK Defaults.USE_CRAM_REF_DOWNLOAD : false
# 01:27:33.096 DEBUG ConfigFactory - Configuration file values:
# 01:27:33.104 DEBUG ConfigFactory - 	gcsMaxRetries = 20
# 01:27:33.104 DEBUG ConfigFactory - 	gcsProjectForRequesterPays =
# 01:27:33.104 DEBUG ConfigFactory - 	gatk_stacktrace_on_user_exception = false
# 01:27:33.104 DEBUG ConfigFactory - 	samjdk.use_async_io_read_samtools = false
# 01:27:33.104 DEBUG ConfigFactory - 	samjdk.use_async_io_write_samtools = true
# 01:27:33.105 DEBUG ConfigFactory - 	samjdk.use_async_io_write_tribble = false
# 01:27:33.105 DEBUG ConfigFactory - 	samjdk.compression_level = 2
# 01:27:33.105 DEBUG ConfigFactory - 	spark.kryoserializer.buffer.max = 512m
# 01:27:33.105 DEBUG ConfigFactory - 	spark.driver.maxResultSize = 0
# 01:27:33.105 DEBUG ConfigFactory - 	spark.driver.userClassPathFirst = true
# 01:27:33.105 DEBUG ConfigFactory - 	spark.io.compression.codec = lzf
# 01:27:33.105 DEBUG ConfigFactory - 	spark.executor.memoryOverhead = 600
# 01:27:33.105 DEBUG ConfigFactory - 	spark.driver.extraJavaOptions =
# 01:27:33.105 DEBUG ConfigFactory - 	spark.executor.extraJavaOptions =
# 01:27:33.105 DEBUG ConfigFactory - 	codec_packages = [htsjdk.variant, htsjdk.tribble, org.broadinstitute.hellbender.utils.codecs]
# 01:27:33.105 DEBUG ConfigFactory - 	read_filter_packages = [org.broadinstitute.hellbender.engine.filters]
# 01:27:33.106 DEBUG ConfigFactory - 	annotation_packages = [org.broadinstitute.hellbender.tools.walkers.annotator]
# 01:27:33.106 DEBUG ConfigFactory - 	cloudPrefetchBuffer = 40
# 01:27:33.106 DEBUG ConfigFactory - 	cloudIndexPrefetchBuffer = -1
# 01:27:33.106 DEBUG ConfigFactory - 	createOutputBamIndex = true
# 01:27:33.106 INFO  DetermineGermlineContigPloidy - Deflater: IntelDeflater
# 01:27:33.106 INFO  DetermineGermlineContigPloidy - Inflater: IntelInflater
# 01:27:33.106 INFO  DetermineGermlineContigPloidy - GCS max retries/reopens: 20
# 01:27:33.106 INFO  DetermineGermlineContigPloidy - Requester pays: disabled
# 01:27:33.108 INFO  DetermineGermlineContigPloidy - Initializing engine
# 01:27:33.111 DEBUG ScriptExecutor - Executing:
# 01:27:33.112 DEBUG ScriptExecutor -   python
# 01:27:33.112 DEBUG ScriptExecutor -   -c
# 01:27:33.112 DEBUG ScriptExecutor -   import gcnvkernel
#
# 01:28:28.592 DEBUG ScriptExecutor - Result: 0
# 01:28:28.597 INFO  DetermineGermlineContigPloidy - Done initializing engine
# 01:28:28.610 INFO  DetermineGermlineContigPloidy - No contig-ploidy model was provided, running in cohort mode...
# 01:28:28.610 INFO  DetermineGermlineContigPloidy - Intervals specified...
# 01:28:29.295 DEBUG GenomeLocParser - Prepared reference sequence contig dictionary
# 01:28:29.298 DEBUG GenomeLocParser -  chr1 (248956422 bp)
# 01:28:29.298 DEBUG GenomeLocParser -  chr2 (242193529 bp)
# 01:28:29.298 DEBUG GenomeLocParser -  chr3 (198295559 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr4 (190214555 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr5 (181538259 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr6 (170805979 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr7 (159345973 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr8 (145138636 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr9 (138394717 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr10 (133797422 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr11 (135086622 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr12 (133275309 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr13 (114364328 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr14 (107043718 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr15 (101991189 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr16 (90338345 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr17 (83257441 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr18 (80373285 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr19 (58617616 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr20 (64444167 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr21 (46709983 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chr22 (50818468 bp)
# 01:28:29.299 DEBUG GenomeLocParser -  chrX (156040895 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chrY (57227415 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chrM (16569 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chr1_KI270706v1_random (175055 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chr1_KI270707v1_random (32032 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chr1_KI270708v1_random (127682 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chr1_KI270709v1_random (66860 bp)
# 01:28:29.300 DEBUG GenomeLocParser -  chr1_KI270710v1_random (40176 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr1_KI270711v1_random (42210 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr1_KI270712v1_random (176043 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr1_KI270713v1_random (40745 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr1_KI270714v1_random (41717 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr2_KI270715v1_random (161471 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr2_KI270716v1_random (153799 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr3_GL000221v1_random (155397 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr4_GL000008v2_random (209709 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr5_GL000208v1_random (92689 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr9_KI270717v1_random (40062 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr9_KI270718v1_random (38054 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr9_KI270719v1_random (176845 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr9_KI270720v1_random (39050 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr11_KI270721v1_random (100316 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr14_GL000009v2_random (201709 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr14_GL000225v1_random (211173 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr14_KI270722v1_random (194050 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr14_GL000194v1_random (191469 bp)
# 01:28:29.301 DEBUG GenomeLocParser -  chr14_KI270723v1_random (38115 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr14_KI270724v1_random (39555 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr14_KI270725v1_random (172810 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr14_KI270726v1_random (43739 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr15_KI270727v1_random (448248 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr16_KI270728v1_random (1872759 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr17_GL000205v2_random (185591 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr17_KI270729v1_random (280839 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr17_KI270730v1_random (112551 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr22_KI270731v1_random (150754 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr22_KI270732v1_random (41543 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr22_KI270733v1_random (179772 bp)
# 01:28:29.302 DEBUG GenomeLocParser -  chr22_KI270734v1_random (165050 bp)
# 01:28:29.303 DEBUG GenomeLocParser -  chr22_KI270735v1_random (42811 bp)
# 01:28:29.303 DEBUG GenomeLocParser -  chr22_KI270736v1_random (181920 bp)
# 01:28:29.304 DEBUG GenomeLocParser -  chr22_KI270737v1_random (103838 bp)
# 01:28:29.304 DEBUG GenomeLocParser -  chr22_KI270738v1_random (99375 bp)
# 01:28:29.304 DEBUG GenomeLocParser -  chr22_KI270739v1_random (73985 bp)
# 01:28:29.305 DEBUG GenomeLocParser -  chrY_KI270740v1_random (37240 bp)
# 01:28:29.305 DEBUG GenomeLocParser -  chrUn_KI270302v1 (2274 bp)
# 01:28:29.305 DEBUG GenomeLocParser -  chrUn_KI270304v1 (2165 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270303v1 (1942 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270305v1 (1472 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270322v1 (21476 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270320v1 (4416 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270310v1 (1201 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270316v1 (1444 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270315v1 (2276 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270312v1 (998 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270311v1 (12399 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270317v1 (37690 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270412v1 (1179 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270411v1 (2646 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270414v1 (2489 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270419v1 (1029 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270418v1 (2145 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270420v1 (2321 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270424v1 (2140 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270417v1 (2043 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270422v1 (1445 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270423v1 (981 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270425v1 (1884 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270429v1 (1361 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270442v1 (392061 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270466v1 (1233 bp)
# 01:28:29.306 DEBUG GenomeLocParser -  chrUn_KI270465v1 (1774 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270467v1 (3920 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270435v1 (92983 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270438v1 (112505 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270468v1 (4055 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270510v1 (2415 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270509v1 (2318 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270518v1 (2186 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270508v1 (1951 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270516v1 (1300 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270512v1 (22689 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270519v1 (138126 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270522v1 (5674 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270511v1 (8127 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270515v1 (6361 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270507v1 (5353 bp)
# 01:28:29.307 DEBUG GenomeLocParser -  chrUn_KI270517v1 (3253 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270529v1 (1899 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270528v1 (2983 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270530v1 (2168 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270539v1 (993 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270538v1 (91309 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270544v1 (1202 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270548v1 (1599 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270583v1 (1400 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270587v1 (2969 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270580v1 (1553 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270581v1 (7046 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270579v1 (31033 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270589v1 (44474 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270590v1 (4685 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270584v1 (4513 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270582v1 (6504 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270588v1 (6158 bp)
# 01:28:29.308 DEBUG GenomeLocParser -  chrUn_KI270593v1 (3041 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270591v1 (5796 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270330v1 (1652 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270329v1 (1040 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270334v1 (1368 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270333v1 (2699 bp)
# 01:28:29.309 DEBUG GenomeLocParser -  chrUn_KI270335v1 (1048 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270338v1 (1428 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270340v1 (1428 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270336v1 (1026 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270337v1 (1121 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270363v1 (1803 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270364v1 (2855 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270362v1 (3530 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270366v1 (8320 bp)
# 01:28:29.310 DEBUG GenomeLocParser -  chrUn_KI270378v1 (1048 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270379v1 (1045 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270389v1 (1298 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270390v1 (2387 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270387v1 (1537 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270395v1 (1143 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270396v1 (1880 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270388v1 (1216 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270394v1 (970 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270386v1 (1788 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270391v1 (1484 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270383v1 (1750 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270393v1 (1308 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270384v1 (1658 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270392v1 (971 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270381v1 (1930 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270385v1 (990 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270382v1 (4215 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270376v1 (1136 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270374v1 (2656 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270372v1 (1650 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270373v1 (1451 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270375v1 (2378 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270371v1 (2805 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270448v1 (7992 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_KI270521v1 (7642 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_GL000195v1 (182896 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_GL000219v1 (179198 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_GL000220v1 (161802 bp)
# 01:28:29.311 DEBUG GenomeLocParser -  chrUn_GL000224v1 (179693 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270741v1 (157432 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_GL000226v1 (15008 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_GL000213v1 (164239 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270743v1 (210658 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270744v1 (168472 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270745v1 (41891 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270746v1 (66486 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270747v1 (198735 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270748v1 (93321 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270749v1 (158759 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270750v1 (148850 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270751v1 (150742 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270752v1 (27745 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270753v1 (62944 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270754v1 (40191 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270755v1 (36723 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270756v1 (79590 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270757v1 (71251 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_GL000214v1 (137718 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_KI270742v1 (186739 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_GL000216v2 (176608 bp)
# 01:28:29.312 DEBUG GenomeLocParser -  chrUn_GL000218v1 (161147 bp)
# 01:28:29.314 DEBUG GenomeLocParser -  chr1_KI270762v1_alt (354444 bp)
# 01:28:29.315 DEBUG GenomeLocParser -  chr1_KI270766v1_alt (256271 bp)
# 01:28:29.315 DEBUG GenomeLocParser -  chr1_KI270760v1_alt (109528 bp)
# 01:28:29.315 DEBUG GenomeLocParser -  chr1_KI270765v1_alt (185285 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_GL383518v1_alt (182439 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_GL383519v1_alt (110268 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_GL383520v2_alt (366580 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_KI270764v1_alt (50258 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_KI270763v1_alt (911658 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_KI270759v1_alt (425601 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr1_KI270761v1_alt (165834 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270770v1_alt (136240 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270773v1_alt (70887 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270774v1_alt (223625 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270769v1_alt (120616 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_GL383521v1_alt (143390 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270772v1_alt (133041 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270775v1_alt (138019 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270771v1_alt (110395 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270768v1_alt (110099 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_GL582966v2_alt (96131 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_GL383522v1_alt (123821 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270776v1_alt (174166 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr2_KI270767v1_alt (161578 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr3_JH636055v2_alt (173151 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr3_KI270783v1_alt (109187 bp)
# 01:28:29.316 DEBUG GenomeLocParser -  chr3_KI270780v1_alt (224108 bp)
# 01:28:29.317 DEBUG GenomeLocParser -  chr3_GL383526v1_alt (180671 bp)
# 01:28:29.317 DEBUG GenomeLocParser -  chr3_KI270777v1_alt (173649 bp)
# 01:28:29.317 DEBUG GenomeLocParser -  chr3_KI270778v1_alt (248252 bp)
# 01:28:29.318 DEBUG GenomeLocParser -  chr3_KI270781v1_alt (113034 bp)
# 01:28:29.318 DEBUG GenomeLocParser -  chr3_KI270779v1_alt (205312 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr3_KI270782v1_alt (162429 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr3_KI270784v1_alt (184404 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270790v1_alt (220246 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_GL383528v1_alt (376187 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270787v1_alt (111943 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_GL000257v2_alt (586476 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270788v1_alt (158965 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_GL383527v1_alt (164536 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270785v1_alt (119912 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270789v1_alt (205944 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr4_KI270786v1_alt (244096 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_KI270793v1_alt (126136 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_KI270792v1_alt (179043 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_KI270791v1_alt (195710 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_GL383532v1_alt (82728 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_GL949742v1_alt (226852 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_KI270794v1_alt (164558 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_GL339449v2_alt (1612928 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_GL383530v1_alt (101241 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_KI270796v1_alt (172708 bp)
# 01:28:29.319 DEBUG GenomeLocParser -  chr5_GL383531v1_alt (173459 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr5_KI270795v1_alt (131892 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_GL000250v2_alt (4672374 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270800v1_alt (175808 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270799v1_alt (152148 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_GL383533v1_alt (124736 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270801v1_alt (870480 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270802v1_alt (75005 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KB021644v2_alt (185823 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270797v1_alt (197536 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr6_KI270798v1_alt (271782 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270804v1_alt (157952 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270809v1_alt (209586 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270806v1_alt (158166 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_GL383534v2_alt (119183 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270803v1_alt (1111570 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270808v1_alt (271455 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270807v1_alt (126434 bp)
# 01:28:29.320 DEBUG GenomeLocParser -  chr7_KI270805v1_alt (209988 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270818v1_alt (145606 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270812v1_alt (282736 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270811v1_alt (292436 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270821v1_alt (985506 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270813v1_alt (300230 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270822v1_alt (624492 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270814v1_alt (141812 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270810v1_alt (374415 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270819v1_alt (133535 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270820v1_alt (36640 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270817v1_alt (158983 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270816v1_alt (305841 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr8_KI270815v1_alt (132244 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr9_GL383539v1_alt (162988 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr9_GL383540v1_alt (71551 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr9_GL383541v1_alt (171286 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr9_GL383542v1_alt (60032 bp)
# 01:28:29.321 DEBUG GenomeLocParser -  chr9_KI270823v1_alt (439082 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr10_GL383545v1_alt (179254 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr10_KI270824v1_alt (181496 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr10_GL383546v1_alt (309802 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr10_KI270825v1_alt (188315 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr11_KI270832v1_alt (210133 bp)
# 01:28:29.322 DEBUG GenomeLocParser -  chr11_KI270830v1_alt (177092 bp)
# 01:28:29.323 DEBUG GenomeLocParser -  chr11_KI270831v1_alt (296895 bp)
# 01:28:29.324 DEBUG GenomeLocParser -  chr11_KI270829v1_alt (204059 bp)
# 01:28:29.324 DEBUG GenomeLocParser -  chr11_GL383547v1_alt (154407 bp)
# 01:28:29.325 DEBUG GenomeLocParser -  chr11_JH159136v1_alt (200998 bp)
# 01:28:29.325 DEBUG GenomeLocParser -  chr11_JH159137v1_alt (191409 bp)
# 01:28:29.325 DEBUG GenomeLocParser -  chr11_KI270827v1_alt (67707 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr11_KI270826v1_alt (186169 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL877875v1_alt (167313 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL877876v1_alt (408271 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_KI270837v1_alt (40090 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL383549v1_alt (120804 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_KI270835v1_alt (238139 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL383550v2_alt (169178 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL383552v1_alt (138655 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL383553v2_alt (152874 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_KI270834v1_alt (119498 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_GL383551v1_alt (184319 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_KI270833v1_alt (76061 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr12_KI270836v1_alt (56134 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270840v1_alt (191684 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270839v1_alt (180306 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270843v1_alt (103832 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270841v1_alt (169134 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270838v1_alt (306913 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr13_KI270842v1_alt (37287 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr14_KI270844v1_alt (322166 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr14_KI270847v1_alt (1511111 bp)
# 01:28:29.326 DEBUG GenomeLocParser -  chr14_KI270845v1_alt (180703 bp)
# 01:28:29.327 DEBUG GenomeLocParser -  chr14_KI270846v1_alt (1351393 bp)
# 01:28:29.327 DEBUG GenomeLocParser -  chr15_KI270852v1_alt (478999 bp)
# 01:28:29.327 DEBUG GenomeLocParser -  chr15_KI270851v1_alt (263054 bp)
# 01:28:29.327 DEBUG GenomeLocParser -  chr15_KI270848v1_alt (327382 bp)
# 01:28:29.327 DEBUG GenomeLocParser -  chr15_GL383554v1_alt (296527 bp)
# 01:28:29.328 DEBUG GenomeLocParser -  chr15_KI270849v1_alt (244917 bp)
# 01:28:29.328 DEBUG GenomeLocParser -  chr15_GL383555v2_alt (388773 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr15_KI270850v1_alt (430880 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_KI270854v1_alt (134193 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_KI270856v1_alt (63982 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_KI270855v1_alt (232857 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_KI270853v1_alt (2659700 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_GL383556v1_alt (192462 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr16_GL383557v1_alt (89672 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_GL383563v3_alt (375691 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_KI270862v1_alt (391357 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_KI270861v1_alt (196688 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_KI270857v1_alt (2877074 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_JH159146v1_alt (278131 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_JH159147v1_alt (70345 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_GL383564v2_alt (133151 bp)
# 01:28:29.329 DEBUG GenomeLocParser -  chr17_GL000258v2_alt (1821992 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr17_GL383565v1_alt (223995 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr17_KI270858v1_alt (235827 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr17_KI270859v1_alt (108763 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr17_GL383566v1_alt (90219 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr17_KI270860v1_alt (178921 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_KI270864v1_alt (111737 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383567v1_alt (289831 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383570v1_alt (164789 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383571v1_alt (198278 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383568v1_alt (104552 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383569v1_alt (167950 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_GL383572v1_alt (159547 bp)
# 01:28:29.330 DEBUG GenomeLocParser -  chr18_KI270863v1_alt (167999 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_KI270868v1_alt (61734 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_KI270865v1_alt (52969 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_GL383573v1_alt (385657 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_GL383575v2_alt (170222 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_GL383576v1_alt (188024 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_GL383574v1_alt (155864 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_KI270866v1_alt (43156 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_KI270867v1_alt (233762 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr19_GL949746v1_alt (987716 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr20_GL383577v2_alt (128386 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr20_KI270869v1_alt (118774 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr20_KI270871v1_alt (58661 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr20_KI270870v1_alt (183433 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_GL383578v2_alt (63917 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_KI270874v1_alt (166743 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_KI270873v1_alt (143900 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_GL383579v2_alt (201197 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_GL383580v2_alt (74653 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_GL383581v2_alt (116689 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr21_KI270872v1_alt (82692 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr22_KI270875v1_alt (259914 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr22_KI270878v1_alt (186262 bp)
# 01:28:29.331 DEBUG GenomeLocParser -  chr22_KI270879v1_alt (304135 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr22_KI270876v1_alt (263666 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr22_KI270877v1_alt (101331 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr22_GL383583v2_alt (96924 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr22_GL383582v2_alt (162811 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chrX_KI270880v1_alt (284869 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chrX_KI270881v1_alt (144206 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270882v1_alt (248807 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270883v1_alt (170399 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270884v1_alt (157053 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270885v1_alt (171027 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270886v1_alt (204239 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270887v1_alt (209512 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270888v1_alt (155532 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270889v1_alt (170698 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270890v1_alt (184499 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr19_KI270891v1_alt (170680 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr1_KI270892v1_alt (162212 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr2_KI270894v1_alt (214158 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr2_KI270893v1_alt (161218 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr3_KI270895v1_alt (162896 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr4_KI270896v1_alt (378547 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr5_KI270897v1_alt (1144418 bp)
# 01:28:29.332 DEBUG GenomeLocParser -  chr5_KI270898v1_alt (130957 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr6_GL000251v2_alt (4795265 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr7_KI270899v1_alt (190869 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr8_KI270901v1_alt (136959 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr8_KI270900v1_alt (318687 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr11_KI270902v1_alt (106711 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr11_KI270903v1_alt (214625 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr12_KI270904v1_alt (572349 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr15_KI270906v1_alt (196384 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr15_KI270905v1_alt (5161414 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr17_KI270907v1_alt (137721 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr17_KI270910v1_alt (157099 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr17_KI270909v1_alt (325800 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr17_JH159148v1_alt (88070 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr17_KI270908v1_alt (1423190 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr18_KI270912v1_alt (174061 bp)
# 01:28:29.333 DEBUG GenomeLocParser -  chr18_KI270911v1_alt (157710 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_GL949747v2_alt (729520 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr22_KB663609v1_alt (74013 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chrX_KI270913v1_alt (274009 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270914v1_alt (205194 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270915v1_alt (170665 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270916v1_alt (184516 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270917v1_alt (190932 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270918v1_alt (123111 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270919v1_alt (170701 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270920v1_alt (198005 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270921v1_alt (282224 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270922v1_alt (187935 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270923v1_alt (189352 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr3_KI270924v1_alt (166540 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr4_KI270925v1_alt (555799 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr6_GL000252v2_alt (4604811 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr8_KI270926v1_alt (229282 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr11_KI270927v1_alt (218612 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_GL949748v2_alt (1064304 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr22_KI270928v1_alt (176103 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270929v1_alt (186203 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270930v1_alt (200773 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270931v1_alt (170148 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270932v1_alt (215732 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_KI270933v1_alt (170537 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_GL000209v2_alt (177381 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr3_KI270934v1_alt (163458 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr6_GL000253v2_alt (4677643 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr19_GL949749v2_alt (1091841 bp)
# 01:28:29.334 DEBUG GenomeLocParser -  chr3_KI270935v1_alt (197351 bp)
# 01:28:29.335 DEBUG GenomeLocParser -  chr6_GL000254v2_alt (4827813 bp)
# 01:28:29.335 DEBUG GenomeLocParser -  chr19_GL949750v2_alt (1066390 bp)
# 01:28:29.335 DEBUG GenomeLocParser -  chr3_KI270936v1_alt (164170 bp)
# 01:28:29.335 DEBUG GenomeLocParser -  chr6_GL000255v2_alt (4606388 bp)
# 01:28:29.335 DEBUG GenomeLocParser -  chr19_GL949751v2_alt (1002683 bp)
# 01:28:29.336 DEBUG GenomeLocParser -  chr3_KI270937v1_alt (165607 bp)
# 01:28:29.337 DEBUG GenomeLocParser -  chr6_GL000256v2_alt (4929269 bp)
# 01:28:29.338 DEBUG GenomeLocParser -  chr19_GL949752v1_alt (987100 bp)
# 01:28:29.338 DEBUG GenomeLocParser -  chr6_KI270758v1_alt (76752 bp)
# 01:28:29.339 DEBUG GenomeLocParser -  chr19_GL949753v2_alt (796479 bp)
# 01:28:29.339 DEBUG GenomeLocParser -  chr19_KI270938v1_alt (1066800 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrEBV (171823 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707606v1_decoy (2200 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707607v1_decoy (3033 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707608v1_decoy (3112 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707609v1_decoy (1642 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707610v1_decoy (1393 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707611v1_decoy (1103 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707612v1_decoy (1039 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707613v1_decoy (1619 bp)
# 01:28:29.340 DEBUG GenomeLocParser -  chrUn_KN707614v1_decoy (3122 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707615v1_decoy (1934 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707616v1_decoy (3111 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707617v1_decoy (2545 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707618v1_decoy (2295 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707619v1_decoy (1551 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707620v1_decoy (2046 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707621v1_decoy (1222 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707622v1_decoy (1535 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707623v1_decoy (3784 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707624v1_decoy (1329 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707625v1_decoy (1238 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707626v1_decoy (5623 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707627v1_decoy (5821 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707628v1_decoy (2960 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707629v1_decoy (1848 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707630v1_decoy (2315 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707631v1_decoy (1945 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707632v1_decoy (1424 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707633v1_decoy (1274 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707634v1_decoy (1007 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707635v1_decoy (1414 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707636v1_decoy (1725 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707637v1_decoy (5354 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707638v1_decoy (2189 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707639v1_decoy (1294 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707640v1_decoy (1831 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707641v1_decoy (1647 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707642v1_decoy (2943 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707643v1_decoy (2857 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707644v1_decoy (1030 bp)
# 01:28:29.341 DEBUG GenomeLocParser -  chrUn_KN707645v1_decoy (1070 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707646v1_decoy (1735 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707647v1_decoy (1982 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707648v1_decoy (1564 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707649v1_decoy (1775 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707650v1_decoy (1540 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707651v1_decoy (2013 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707652v1_decoy (1176 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707653v1_decoy (1890 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707654v1_decoy (3644 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707655v1_decoy (2785 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707656v1_decoy (1017 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707657v1_decoy (1068 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707658v1_decoy (1007 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707659v1_decoy (2605 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707660v1_decoy (8410 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707661v1_decoy (5534 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707662v1_decoy (2173 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707663v1_decoy (1065 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707664v1_decoy (8683 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707665v1_decoy (2670 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707666v1_decoy (2420 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707667v1_decoy (2189 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707668v1_decoy (2093 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707669v1_decoy (1184 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707670v1_decoy (1205 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707671v1_decoy (2786 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707672v1_decoy (2794 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707673v1_decoy (19544 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707674v1_decoy (2848 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707675v1_decoy (10556 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707676v1_decoy (9066 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707677v1_decoy (7267 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707678v1_decoy (2462 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707679v1_decoy (1774 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707680v1_decoy (1297 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707681v1_decoy (4379 bp)
# 01:28:29.342 DEBUG GenomeLocParser -  chrUn_KN707682v1_decoy (4208 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707683v1_decoy (4068 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707684v1_decoy (2940 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707685v1_decoy (3938 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707686v1_decoy (2072 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707687v1_decoy (1136 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707688v1_decoy (4248 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707689v1_decoy (5823 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707690v1_decoy (3715 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707691v1_decoy (4885 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707692v1_decoy (4813 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707693v1_decoy (2899 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707694v1_decoy (1228 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707695v1_decoy (3119 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707696v1_decoy (3828 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707697v1_decoy (1186 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707698v1_decoy (1908 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707699v1_decoy (2795 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707700v1_decoy (3703 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707701v1_decoy (6722 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707702v1_decoy (6466 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707703v1_decoy (2235 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707704v1_decoy (2871 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707705v1_decoy (4632 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707706v1_decoy (4225 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707707v1_decoy (4339 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707708v1_decoy (2305 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707709v1_decoy (3273 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707710v1_decoy (5701 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707711v1_decoy (4154 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707712v1_decoy (1243 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707713v1_decoy (1308 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707714v1_decoy (2922 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707715v1_decoy (3044 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707716v1_decoy (2888 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707717v1_decoy (1742 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707718v1_decoy (4969 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707719v1_decoy (3270 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707720v1_decoy (6028 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707721v1_decoy (1105 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707722v1_decoy (2884 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707723v1_decoy (1124 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707724v1_decoy (1454 bp)
# 01:28:29.343 DEBUG GenomeLocParser -  chrUn_KN707725v1_decoy (2565 bp)
# 01:28:29.344 DEBUG GenomeLocParser -  chrUn_KN707726v1_decoy (2149 bp)
# 01:28:29.344 DEBUG GenomeLocParser -  chrUn_KN707727v1_decoy (2630 bp)
# 01:28:29.344 DEBUG GenomeLocParser -  chrUn_KN707728v1_decoy (14625 bp)
# 01:28:29.345 DEBUG GenomeLocParser -  chrUn_KN707729v1_decoy (7431 bp)
# 01:28:29.345 DEBUG GenomeLocParser -  chrUn_KN707730v1_decoy (5776 bp)
# 01:28:29.346 DEBUG GenomeLocParser -  chrUn_KN707731v1_decoy (4820 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707732v1_decoy (1227 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707733v1_decoy (7503 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707734v1_decoy (9652 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707735v1_decoy (1091 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707736v1_decoy (2467 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707737v1_decoy (1270 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707738v1_decoy (4365 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707739v1_decoy (4284 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707740v1_decoy (10282 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707741v1_decoy (5601 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707742v1_decoy (4758 bp)
# 01:28:29.347 DEBUG GenomeLocParser -  chrUn_KN707743v1_decoy (1624 bp)
# 01:28:29.348 DEBUG GenomeLocParser -  chrUn_KN707744v1_decoy (4024 bp)
# 01:28:29.348 DEBUG GenomeLocParser -  chrUn_KN707745v1_decoy (1276 bp)
# 01:28:29.348 DEBUG GenomeLocParser -  chrUn_KN707746v1_decoy (5083 bp)
# 01:28:29.348 DEBUG GenomeLocParser -  chrUn_KN707747v1_decoy (2075 bp)
# ...
# 01:34:24.751 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 13) relative error: 0.0004 +/- 0.0025:   3%|3         | 3/100 [00:00<00:09, 10.71it/s]
# 01:34:24.752 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 13):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:24.752 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 13) ploidy update size: 0.000404586:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:24.752 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:24.853 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -16.035 +/- 0.198, SNR: 1.3, T: 1.00:  13%|#3        | 66/500 [00:00<00:00, 658.50it/s]
# 01:34:24.959 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -16.004 +/- 0.189, SNR: 1.2, T: 1.00:  26%|##6       | 132/500 [00:00<00:00, 636.96it/s]
# 01:34:25.160 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.978 +/- 0.184, SNR: 1.1, T: 1.00:  39%|###9      | 196/500 [00:00<00:00, 439.83it/s]
# 01:34:25.270 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.958 +/- 0.179, SNR: 1.0, T: 1.00:  52%|#####1    | 258/500 [00:00<00:00, 479.32it/s]
# 01:34:25.418 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.943 +/- 0.175, SNR: 0.9, T: 1.00:  62%|######2   | 310/500 [00:00<00:00, 430.87it/s]
# 01:34:25.518 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.926 +/- 0.170, SNR: 0.9, T: 1.00:  73%|#######2  | 363/500 [00:00<00:00, 457.09it/s]
# 01:34:25.619 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.905 +/- 0.164, SNR: 0.8, T: 1.00:  86%|########5 | 428/500 [00:00<00:00, 510.15it/s]
# 01:34:25.717 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 14) ELBO: -15.880 +/- 0.156, SNR: 0.7, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 518.48it/s]
# 01:34:25.717 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 14):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:25.872 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 14) relative error: 0.0021 +/- 0.0053:   2%|2         | 2/100 [00:00<00:07, 12.98it/s]
# 01:34:25.954 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 14) relative error: 0.0001 +/- 0.0023:   2%|2         | 2/100 [00:00<00:11,  8.45it/s]
# 01:34:25.955 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 14):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:25.956 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 14) ploidy update size: 7.60277e-05:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:25.957 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:26.059 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.862 +/- 0.150, SNR: 0.6, T: 1.00:  16%|#5        | 79/500 [00:00<00:00, 780.75it/s]
# 01:34:26.165 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.848 +/- 0.146, SNR: 0.5, T: 1.00:  32%|###1      | 158/500 [00:00<00:00, 756.44it/s]
# 01:34:26.279 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.835 +/- 0.142, SNR: 0.4, T: 1.00:  47%|####6     | 234/500 [00:00<00:00, 714.32it/s]
# 01:34:26.384 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.826 +/- 0.140, SNR: 0.4, T: 1.00:  61%|######1   | 306/500 [00:00<00:00, 704.93it/s]
# 01:34:26.484 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.814 +/- 0.136, SNR: 0.3, T: 1.00:  77%|#######7  | 385/500 [00:00<00:00, 733.94it/s]
# 01:34:26.584 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.803 +/- 0.133, SNR: 0.2, T: 1.00:  93%|#########2| 463/500 [00:00<00:00, 748.31it/s]
# 01:34:26.626 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 15) ELBO: -15.799 +/- 0.132, SNR: 0.2, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 747.65it/s]
# 01:34:26.626 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 15):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:26.785 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 15) relative error: 0.0009 +/- 0.0091:   2%|2         | 2/100 [00:00<00:07, 12.65it/s]
# 01:34:26.930 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 15) relative error: 0.0003 +/- 0.0012:   3%|3         | 3/100 [00:00<00:09,  9.89it/s]
# 01:34:26.930 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 15):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:26.931 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 15) ploidy update size: 0.000562073:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:26.931 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:27.034 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.795 +/- 0.131, SNR: 0.1, T: 1.00:  15%|#5        | 75/500 [00:00<00:00, 726.37it/s]
# 01:34:27.157 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.793 +/- 0.130, SNR: 0.1, T: 1.00:  30%|##9       | 148/500 [00:00<00:00, 644.55it/s]
# 01:34:27.257 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.789 +/- 0.128, SNR: 0.1, T: 1.00:  45%|####5     | 225/500 [00:00<00:00, 696.21it/s]
# 01:34:27.361 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.787 +/- 0.128, SNR: 0.1, T: 1.00:  59%|#####9    | 296/500 [00:00<00:00, 691.88it/s]
# 01:34:27.482 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.783 +/- 0.127, SNR: 0.1, T: 1.00:  73%|#######3  | 366/500 [00:00<00:00, 646.80it/s]
# 01:34:27.583 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.780 +/- 0.126, SNR: 0.1, T: 1.00:  87%|########7 | 437/500 [00:00<00:00, 665.89it/s]
# 01:34:27.666 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 16) ELBO: -15.777 +/- 0.125, SNR: 0.0, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 680.37it/s]
# 01:34:27.666 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 16):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:27.809 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 16) relative error: 0.0011 +/- 0.0074:   2%|2         | 2/100 [00:00<00:06, 14.05it/s]
# 01:34:27.897 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 16) relative error: 0.0004 +/- 0.0032:   2%|2         | 2/100 [00:00<00:11,  8.67it/s]
# 01:34:27.898 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 16):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:27.899 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 16) ploidy update size: 0.000519708:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:27.899 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:28.000 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.778 +/- 0.125, SNR: 0.0, T: 1.00:  13%|#2        | 63/500 [00:00<00:00, 626.43it/s]
# 01:34:28.102 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.776 +/- 0.124, SNR: 0.0, T: 1.00:  28%|##8       | 141/500 [00:00<00:00, 709.64it/s]
# 01:34:28.204 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.775 +/- 0.123, SNR: 0.0, T: 1.00:  42%|####2     | 212/500 [00:00<00:00, 702.68it/s]
# 01:34:28.308 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.772 +/- 0.127, SNR: 0.0, T: 1.00:  58%|#####8    | 292/500 [00:00<00:00, 728.34it/s]
# 01:34:28.408 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.771 +/- 0.129, SNR: 0.0, T: 1.00:  75%|#######4  | 373/500 [00:00<00:00, 756.86it/s]
# 01:34:28.509 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.771 +/- 0.129, SNR: 0.0, T: 1.00:  90%|######### | 451/500 [00:00<00:00, 763.09it/s]
# 01:34:28.584 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 17) ELBO: -15.771 +/- 0.129, SNR: 0.0, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 730.49it/s]
# 01:34:28.584 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 17):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:28.740 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 17) relative error: 0.0016 +/- 0.0046:   2%|2         | 2/100 [00:00<00:07, 12.87it/s]
# 01:34:28.883 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 17) relative error: 0.0004 +/- 0.0017:   3%|3         | 3/100 [00:00<00:09, 10.05it/s]
# 01:34:28.883 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 17):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:28.888 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 17) ploidy update size: 0.00101179: 100%|##########| 1/1 [00:00<00:00, 223.74it/s]
# 01:34:28.888 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:28.990 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.773 +/- 0.129, SNR: 0.0, T: 1.00:  11%|#1        | 55/500 [00:00<00:00, 540.28it/s]
# 01:34:29.090 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.773 +/- 0.128, SNR: 0.0, T: 1.00:  24%|##3       | 119/500 [00:00<00:00, 598.21it/s]
# 01:34:29.191 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.773 +/- 0.128, SNR: 0.0, T: 1.00:  37%|###7      | 186/500 [00:00<00:00, 627.88it/s]
# 01:34:29.291 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.774 +/- 0.127, SNR: 0.0, T: 1.00:  53%|#####2    | 263/500 [00:00<00:00, 682.97it/s]
# 01:34:29.391 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.774 +/- 0.127, SNR: 0.0, T: 1.00:  68%|######7   | 339/500 [00:00<00:00, 710.27it/s]
# 01:34:29.498 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.774 +/- 0.129, SNR: 0.0, T: 1.00:  82%|########2 | 411/500 [00:00<00:00, 698.13it/s]
# 01:34:29.598 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.773 +/- 0.129, SNR: 0.0, T: 1.00:  98%|#########7| 489/500 [00:00<00:00, 723.38it/s]
# 01:34:29.631 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 18) ELBO: -15.773 +/- 0.129, SNR: 0.0, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 673.10it/s]
# 01:34:29.631 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 18):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:29.759 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 18) relative error: 0.0011 +/- 0.0056:   2%|2         | 2/100 [00:00<00:06, 15.64it/s]
# 01:34:29.910 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 18) relative error: 0.0004 +/- 0.0019:   3%|3         | 3/100 [00:00<00:09, 10.76it/s]
# 01:34:29.911 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 18):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:29.911 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 18) ploidy update size: 0.000801414:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:29.911 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:30.014 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.773 +/- 0.128, SNR: 0.0, T: 1.00:  13%|#3        | 67/500 [00:00<00:00, 655.80it/s]
# 01:34:30.128 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.775 +/- 0.128, SNR: 0.0, T: 1.00:  27%|##6       | 133/500 [00:00<00:00, 606.40it/s]
# 01:34:30.229 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.775 +/- 0.129, SNR: 0.0, T: 1.00:  41%|####1     | 205/500 [00:00<00:00, 654.24it/s]
# 01:34:30.331 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.775 +/- 0.128, SNR: 0.0, T: 1.00:  61%|######1   | 306/500 [00:00<00:00, 785.08it/s]
# 01:34:30.440 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.775 +/- 0.129, SNR: 0.0, T: 1.00:  77%|#######7  | 386/500 [00:00<00:00, 766.32it/s]
# 01:34:30.541 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.774 +/- 0.129, SNR: 0.0, T: 1.00:  93%|#########2| 464/500 [00:00<00:00, 767.01it/s]
# 01:34:30.612 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 19) ELBO: -15.774 +/- 0.129, SNR: 0.0, T: 1.00: 100%|##########| 500/500 [00:00<00:00, 713.64it/s]
# 01:34:30.613 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 19):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:30.758 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 19) relative error: 0.0006 +/- 0.0081:   2%|2         | 2/100 [00:00<00:07, 13.76it/s]
# 01:34:30.838 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 19) relative error: 0.0005 +/- 0.0020:   2%|2         | 2/100 [00:00<00:11,  8.86it/s]
# 01:34:30.839 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 19):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:30.839 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 19) ploidy update size: 0.000193127:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:30.839 INFO gcnvkernel.tasks.inference_task_base - (denoising) starting...:   0%|          | 0/500 [00:00<?, ?it/s]
# 01:34:30.854 INFO gcnvkernel.tasks.inference_task_base - (denoising epoch 20) ELBO: -15.774 +/- 0.129, SNR: 0.0, T: 1.00:   2%|1         | 9/500 [00:00<00:00, 612.00it/s]
# 01:34:30.854 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 20):   0%|          | 0/100 [00:00<?, ?it/s]
# 01:34:31.001 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 20) relative error: 0.0014 +/- 0.0068:   2%|2         | 2/100 [00:00<00:07, 13.66it/s]
# 01:34:31.084 INFO gcnvkernel.tasks.inference_task_base - (sampling epoch 20) relative error: 0.0004 +/- 0.0029:   2%|2         | 2/100 [00:00<00:11,  8.72it/s]
# 01:34:31.084 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 20):   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:31.085 INFO gcnvkernel.tasks.inference_task_base - (ploidy calling epoch 20) ploidy update size: 0.000111239:   0%|          | 0/1 [00:00<?, ?it/s]
# 01:34:31.085 INFO gcnvkernel.tasks.inference_task_base - Inference task completed successfully and convergence achieved.
# 01:34:32.569 INFO gcnvkernel.io.io_ploidy - Writing mean_bias_j_lowerbound__...
# 01:34:32.615 INFO gcnvkernel.io.io_ploidy - Writing psi_j_log__...
# 01:34:32.642 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA18525" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_0"...
# 01:34:32.656 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA18939" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_1"...
# 01:34:32.668 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA19017" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_2"...
# 01:34:32.680 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA19625" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_3"...
# 01:34:32.692 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA19648" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_4"...
# 01:34:32.706 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA20502" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_5"...
# 01:34:32.717 INFO gcnvkernel.io.io_ploidy - Saving posteriors for sample "NA20845" in "/home/jupyter/notebooks/germline-cnv/sandbox/ploidy-cohort7-calls/SAMPLE_6"...
# 01:34:33.262 DEBUG ScriptExecutor - Result: 0
# 01:34:33.268 INFO  DetermineGermlineContigPloidy - DetermineGermlineContigPloidy complete.
# 01:34:33.268 INFO  DetermineGermlineContigPloidy - Shutting down engine
# [January 20, 2024 at 1:34:33 AM GMT] org.broadinstitute.hellbender.tools.copynumber.DetermineGermlineContigPloidy done. Elapsed time: 7.01 minutes.
# Runtime.totalMemory()=548405248

# %% [markdown]
# This produces a `<output-prefix>-calls` directory and a `<output-prefix>-model` directory.
#
# The ploidy-calls directory contains a folder of data for each sample in the cohort including the contig ploidy calls. Each sample directory, e.g. `ploidy-calls/SAMPLE_0`, contains five files:

# %%
! ls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls

# %%
! ls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls/SAMPLE_0

# %%
# let's look at the ploidy calls for NA19017
! cat $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls/SAMPLE_2/sample_name.txt
! cat $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls/SAMPLE_2/contig_ploidy.tsv

# %% [markdown]
# Description of output files:
# - `contig_ploidy.tsv` notes the ploidy and genotype quality (GQ) of the ploidy call for each contig.
# - `global_read_depth.tsv` notes an average depth value and an average ploidy across all the intervals of the sample.
# - `mu_psi_s_log__.tsv` captures the posterior mean for all of the modeled parameters.
# - `sample_name.txt` contains the readgroup sample (RG SM) name.
# - `std_psi_s_log__.tsv` captures the standard deviation for all of the modeled paramters.

# %%
! ls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-model

# %% [markdown]
# The ploidy-model directory contains aggregated model data for the cohort. This is the model to provide to a case-mode _DetermineGermlineContigPloidy_ analysis and to _GermlineCNVCaller_. The tutorial ploidy-model directory contains the eight files as follows.
#
# - `contig_ploidy_prior.tsv` is a copy of the ploidy priors given to the tool.
# - `gcnvkernel_version.json` notes the version of the kernel.
# - `interval_list.tsv` recapitulates the intervals used, e.g. the filtered intervals.
# - `mu_mean_bias_j_lowerbound__.tsv` is the estimated contig-level capture bias (mean).
# - `mu_psi_j_log__.tsv` is the estimated contig-level capture noise (mean).
# - `ploidy_config.json` configuration of the ploidy model
# - `std_mean_bias_j_lowerbound__.tsv` is the estimated contg-level capture bias (std).
# - `std_psi_j_log__.tsv` is the estimated contig-level capture noise (std).
#
# Note: The PyMC3/Theano model automatically generates mu_ and std_ files and may append transformations it performs to the file name, e.g. log or lowerbound as we see above. These are likely of interest only to advanced users.

# %% [markdown]
# In preparation for the next section (i.e. running the tool in case mode), let us run _DetermineGermlineContigPloidy_ one more time, but assuming that we didn't have `NA19017` sample in the original cohort:

# %%
# --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 args only used 
# for tutorial to decrease training time. Not recommeneded for use with full size data.

! gatk DetermineGermlineContigPloidy \
        -L $WORKSPACE_LOCAL/sandbox/chr20Y.cohort.gc.filtered.interval_list \
        --interval-merging-rule OVERLAPPING_ONLY \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-priors $TUTORIAL_DATA_PATH/chr20XY_contig_ploidy_priors.tsv \
        --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 \
        --output $WORKSPACE_LOCAL/sandbox \
        --output-prefix ploidy-cohort6 \
        --verbosity DEBUG

# %% [markdown]
# ## _DetermineGermlineContigPloidy_ in case mode
#
# The case mode calls contig ploidies for each sample against the ploidy model given by `--model`. The following command runs sample NA19017 against the 23-sample cohort model we built above:

# %%
# --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 args only used 
# for tutorial to decrease training time. Not recommeneded for use with full size data.

! gatk DetermineGermlineContigPloidy \
        --model $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-model \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        -O $WORKSPACE_LOCAL/sandbox \
        --output-prefix ploidy-cohort6-case \
        --max-training-epochs 20 --num-thermal-advi-iters 1000 --max-advi-iter-subsequent-epochs 500 \
        --verbosity DEBUG

# %% [markdown]
# This produces a ploidy-case-calls directory, which in turn contains a directory of sample data, SAMPLE_0. A list of the five resulting files is some paragraphs above:

# %%
! ls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls/SAMPLE_0

# %%
# let's look at the ploidy calls for the case sample (NA19017)
! cat $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls/SAMPLE_0/sample_name.txt
! cat $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls/SAMPLE_0/contig_ploidy.tsv

# %% [markdown]
# ### Comments on select parameters of _DetermineGermlineContigPloidy_
#
# - It is possible to analyze multiple samples simultaneously in a case mode command. Provide each sample with `-I`.
# - For the `-L` intervals, supply the most processed intervals list. For the tutorial, this is the filtered intervals. Note the case mode does not require explicit intervals because the ploidy model provides them.
# - Provide a `--contig-ploidy-priors` table containing the per-contig prior probabilities for integer ploidy state. Again, the case mode does not require an explicit priors file as the ploidy model provides them. Tool index describes this resource in detail.
# - Optionally provide intervals to exclude from analysis with `--exclude-intervals` or `-XL`, e.g. [pseudoautosomal (PAR) regions](https://gatk.zendesk.com/hc/en-us/articles/360035891071), which can skew the results on sex chromosomes.

# %% [markdown]
# # Call copy-number variants with _GermlineCNVCaller_

# %% [markdown]
# _GermlineCNVCaller_ learns a denoising model per scattered shard while consistently calling CNVs across the shards. The tool models systematic biases and CNVs simultaneously, which allows for sensitive detection of both rare and common CNVs. As the tool index states under Important Remarks (v4.1.0.0), the tool should see data from a large enough genomic region so as to be exposed to diverse genomic features. The current recommendation is to provide at least ~10–50Mbp genomic coverage per scatter. This applies to exomes or WGS. This allows reliable inference of bias factors including GC bias. The limitation of analyzing larger regions is available memory. As an analysis covers more data, memory requirements increase.
#
# For expediency, the tutorial commands below analyze small data, specifically the 1400 bins in `twelveregions.cohort.gc.filtered.interval_list` and use default parameters. The tutorial splits the 1400 bins into two shards with 700 bins each to illustrate scattering. This results in ~0.7Mbp genomic coverage per shard. See section 5.2.3 for how to split interval lists by a given number of intervals. Default inference parameters are conservatively set for efficient run times.

# %% [markdown]
# ## _GermlineCNVCaller_ in cohort mode
#
# This cell produces per-interval gCNV calls for each of the cohort samples and a gCNV model for the cohort. Each command produces three directories within `gcnv-cohort24-twelve`:
# - a `gcnv-cohort24-twelve-1of2-calls` folder of per sample gCNV call results,
# - a `gcnv-cohort24-twelve-1of2-model` folder of cohort model data,
# - a `gcnv-cohort24-twelve-1of2-tracking` folder of data that tracks model fitting.
#
# Note: Each shard should finish under 10 minutes in this Terra VM (4 vCPUs).  When running the default parameters of the v4.1.0.0 WDL cohort-mode workflow on the cloud, the majority of the shard analyses complete in half an hour.

# %% [markdown]
# **First shard (24 samples)**

# %%
! gatk GermlineCNVCaller \
        --run-mode COHORT \
        -L $TUTORIAL_DATA_PATH/scatter-sm/twelve_1of2.interval_list \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls \
        --annotated-intervals $TUTORIAL_DATA_PATH/twelveregions.annotated.tsv \
        --interval-merging-rule OVERLAPPING_ONLY \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve \
        --output-prefix gcnv-cohort7-twelve-1of2 \
        --verbosity DEBUG

# %% [markdown]
# **Second shard (24 samples)**

# %%
! gatk GermlineCNVCaller \
        --run-mode COHORT \
        -L $TUTORIAL_DATA_PATH/scatter-sm/twelve_2of2.interval_list \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls \
        --annotated-intervals $TUTORIAL_DATA_PATH/twelveregions.annotated.tsv \
        --interval-merging-rule OVERLAPPING_ONLY \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve \
        --output-prefix gcnv-cohort7-twelve-2of2 \
        --verbosity DEBUG

# %%
# let's get acquainted with the output
! ls $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-model

# %% [markdown]
# **(advanced)** The model directory contains aggregated model data for the cohort and the analyzed interval shard. This is the model to provide to a case-mode _GermlineCNVCaller_. The model files are as follows:
#
# - `calling_config.json` is the configuration of the copy-number caller sub-model (the two-level HMM)
# - `denoising_config.json` is the configuration of the read-count noise model
# - `gcnvkernel_version.json` notes the version of the gcnvkernel
# - `interval_list.tsv` recapitulates the intervals used in this shard
# - `log_q_tau_tk.tsv` is the posterior probability of region class (rare vs. common) in log-scale
# - `mu_ard_u_log__.tsv` is ARD coefficient of the bias factors in log-scale (mean)
# - `mu_log_mean_bias_t.tsv` is the mean read-count capture bias of each of interval (mean)
# - `mu_psi_t_log__.tsv` is the read-count unexplained variance (overdispersion) of each of interval in log-scale (mean)
# - `mu_W_tu.tsv` is the interval x number of bias factors matrix of learned bias factors (mean)
# - `std_ard_u_log__.tsv` is ARD coefficient of the bias factors in log-scale (std)
# - `std_log_mean_bias_t.tsv` is the mean read-count capture bias of each of interval (std)
# - `std_psi_t_log__.tsv` is the read-count unexplained variance (overdispersion) of each of interval in log-scale (std)
# - `std_W_tu.tsv` is the interval x number of bias factors matrix of learned bias factors (std)
# Note: The PyMC3/Theano model automatically generates mu_ and std_ prefixed files and may append transformations it performs to the file name (e.g. log) as we see above. These are likely of interest only to advanced users who may want to inspect the model parameters.

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-tracking

# %% [markdown]
# **(advanced)** Loss function trajectory during model training:
#
# - `warm_up_elbo_history.tsv` is evidence lower bound (ELBO) history during the initial model warm-up period
# - `main_elbo_history.tsv` is evidence lower bound (ELBO) history during the main model training period

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-calls

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-calls/SAMPLE_0

# %% [markdown]
# **(advanced)** The calls directory contains various sample-specific estimated quantities, including per-interval estimated copy-number states. These intermediate results are later post-processed by `PostprocessGermlineCNVCalls` to produce VCF files (see the next section). The per-sample call files are as follows:
#
# - `baseline_copy_number_t.tsv` is the per-interval baseline copy-number of the sample (recapitulated from DetermineGermlineContigPloidy)
# - `log_c_emission_tc.tsv` is the emission probability of each interval to different copy-number states in log-scale
# - `log_q_c_tc.tsv` is the per-interval posterior probability of each copy-number state in log-scale
# - `mu_denoised_copy_ratio_t.tsv` is the per-interval denoised copy-ratio
# - `mu_psi_s_log__.tsv` is the global unexplained variance (overdispersion) of this sample in log-scale (mean)
# - `mu_read_depth_s_log__.tsv` is the global read-depth of this sample in log-scale (mean)
# - `mu_z_sg.tsv` is loading of each GC bin (related to GC bias correction) (mean)
# - `mu_z_su.tsv` is the loading of each bias factor (mean)
# - `sample_name.txt` is the name of the sample
# - `std_denoised_copy_ratio_t.tsv` is the per-interval denoised copy-ratio
# - `std_psi_s_log__.tsv` is the global unexplained variance (overdispersion) of this sample in log-scale (std)
# - `std_read_depth_s_log__.tsv` is the global read-depth of this sample in log-scale (std)
# - `std_z_sg.tsv` is loading of each GC bin (related to GC bias correction) (std)
# - `std_z_su.tsv` is the loading of each bias factor (std)
# Note: The PyMC3/Theano model automatically generates mu_ and std_ prefixed files and may append transformations it performs to the file name (e.g. log__) as we see above. These are likely of interest only to advanced users who may want to inspect the model parameters.

# %% [markdown]
# To test _GermlineCNVCaller_ in case mode, let us assume we didn't have sample `NA19017` in the initial cohort and let us build a cohort of 23 samples. We will then run _GermlineCNVCaller_ in case mode using the model learned from the 23-sample cohort.

# %% [markdown]
# **First shard (23 samples)**

# %%
! gatk GermlineCNVCaller \
        --run-mode COHORT \
        -L $TUTORIAL_DATA_PATH/scatter-sm/twelve_1of2.interval_list \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-calls \
        --annotated-intervals $TUTORIAL_DATA_PATH/twelveregions.annotated.tsv \
        --interval-merging-rule OVERLAPPING_ONLY \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve \
        --output-prefix gcnv-cohort6-twelve-1of2 \
        --verbosity DEBUG

# %% [markdown]
# **Second shard (23 samples)**

# %%
! gatk GermlineCNVCaller \
        --run-mode COHORT \
        -L $TUTORIAL_DATA_PATH/scatter-sm/twelve_2of2.interval_list \
        -I $TUTORIAL_DATA_PATH/cvg/NA18525.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA18939.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19625.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA19648.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20502.tsv \
        -I $TUTORIAL_DATA_PATH/cvg/NA20845.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-calls \
        --annotated-intervals $TUTORIAL_DATA_PATH/twelveregions.annotated.tsv \
        --interval-merging-rule OVERLAPPING_ONLY \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve \
        --output-prefix gcnv-cohort6-twelve-2of2 \
        --verbosity DEBUG

# %% [markdown]
# ## _GermlineCNVCaller_ in case mode
#
# Call gCNVs on a sample against a cohort model. The case analysis must use the same scatter approach as the model generation. So, as above, we run two shard analyses. Here, `--model` and `--output-prefix` differ between the scatter the commands.

# %% [markdown]
# **First shard (case-calling sample `NA19017` against the model built from the 23-sample cohort)**

# %%
! gatk GermlineCNVCaller \
        --run-mode CASE \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls \
        --model $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve/gcnv-cohort6-twelve-1of2-model \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6 \
        --output-prefix gcnv-case-twelve-vs-cohort6-1of2 \
        --verbosity DEBUG

# %% [markdown]
# **Second shard (case-calling sample `NA19017` against the model built from the 6-sample cohort)**

# %%
! gatk GermlineCNVCaller \
        --run-mode CASE \
        -I $TUTORIAL_DATA_PATH/cvg/NA19017.tsv \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls \
        --model $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve/gcnv-cohort6-twelve-2of2-model \
        --output $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6 \
        --output-prefix gcnv-case-twelve-vs-cohort6-2of2 \
        --verbosity DEBUG

# %%
# let's get acquainted with the output
! ls $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6/gcnv-case-twelve-vs-cohort6-1of2-calls

# %%
! ls $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6/gcnv-case-twelve-vs-cohort6-1of2-calls/SAMPLE_0

# %% [markdown]
# The call output in the case mode is similar to the cohort mode.

# %% [markdown]
# At this point, the workflow has done its most heavy lifting to produce data towards copy number calling. In Section 5, we consolidate the data from the scattered GermlineCNVCaller runs, perform segmentation and call copy number states.

# %% [markdown]
# ### Comments on select parameters of _GermlineCNVCaller_
#
# - The `-O` output directory must be extant before running the command. Future releases (v4.1.1.0) will create the directory.
# - The default `--max-copy-number` is capped at 5. This means the tool reports any events with more copies as CN5.
# - For the cohort mode, optionally provide `--annotated-intervals` to include the annotations as covariates. These must contain all of the `-L` intervals. The `-L` intervals is an exact match or a subset of the annotated intervals.
# - For the case mode, the tool accepts only a single `--model` directory at a time. So the case must be analyzed with the same number of scatters as the cohort model run. The case mode parameters appear fewer than the cohort mode because the `--model` directory provides the seemingly missing requirements, i.e. the scatter intervals and the annotated intervals.
# - For both modes, provide the `--contig-ploidy-calls` results from _DetermineGermlineContigPloidy_ (Section 4).
# - `--verbosity DEBUG` allows tracking the Python `gcnvkernel` model fitting in the stdout, e.g. with information on denoising epochs and whether the model converged. The default INFO level verbosity is the next most verbose and emits only GATK Engine level messages.

# %% [markdown]
# ### How do I increase the sensitivity of CNV detection?
#
# The tutorial uses default _GermlineCNVCaller_ modeling parameters. However, researchers should expect to tune parameters for data, e.g. from different sequencing technologies. For tuning, first consider the coherence length parameters, `p-alt`, `p-active` and the `psi-scale` parameters. These hyperparameters are just a few of the plethora of adjustable parameters _GermlineCNVCaller_ offers. Refer to the GermlineCNVCaller tool documentation for detailed explanations, and ask on the GATK Forum for further guidance.
#
# One set of parameter changes for WGS data that dramatically increase the sensitivity of calling on the tutorial data:
# ```
#     --class-coherence-length 1000.0 \
#     --cnv-coherence-length 1000.0 \
#     --enable-bias-factors false \
#     --interval-psi-scale 1.0E-6 \
#     --log-mean-bias-standard-deviation 0.01 \
#     --sample-psi-scale 1.0E-6 \
# ```
#
# Article #11687 and Notebook #11686 compare the results of using default vs. the increased-sensitivity parameters. Given the absence of off-the-shelf filtering solutions for CNV calls, when tuning parameters to increase sensitivity, researchers should expect to perform additional due diligence, especially for analyses requiring high precision calls.
#
# **Comments on select sensitivity parameters**
#
# - Decreasing `--class-coherence-length` from its default of `10,000bp` to `1000bp` decreases the expected length of contiguous segments of genomic region classes (silent vs. active). Factor for bin size when tuning.
# - Decreasing `--cnv-coherence-length` from its default `10,000bp` to `1000bp` decreases the expected length of per-sample CNV events. Factor for bin size when tuning.
# - Turning off `--enable-bias-factors` from the default true state to false turns off active discovery of learnable bias factors. This should always be on for targeted exome data and in general can be turned off for WGS data.
# - Decreasing `--interval-psi-scale` from its default of `0.001` to `1.0E-6` reduces the scale the tool considers normal in per-interval noise.
# - Decreasing `--log-mean-bias-standard-deviation` from its default of `0.1` to `0.01` reduces what is considered normal noise in capture bias.
# - Decreasing `--sample-psi-scale` from its default of `0.0001` to `1.0E-6` reduces the scale that is considered normal in sample-specific global read-count overdispersion.
#
#
# Additional parameters to consider include `--depth-correction-tau`, `--p-active` and `--p-alt`:
#
# - `--depth-correction-tau` has a default of `10000.0` (10K) and defines the precision of read-depth concordance with the prior estimate.
# - `--p-active` has a default of `1e-2` (0.01) and defines the prior probability of designating common CNV genomic regions.
# - `--p-alt` has a default of `1e-6` (0.000001) and defines the expected probability of CNV events (in silent genomic regions).

# %% [markdown]
# ### How do I make interval lists for scattering (genomic sharding)?

# %% [markdown]
# This step applies to the cohort mode. It is unnecessary for case mode analyses as the model implies the scatter intervals.
#
# The v4.1.0.0 `cnv_germline_cohort_workflow.wdl` pipeline workflow scatters the _GermlineCNVCaller_ step. Each scattered analysis is on genomic intervals subset from intervals produced either from _PreprocessIntervals_ (section 2) or from _FilterIntervals_ (section 3). The workflow uses Picard _IntervalListTools_ to break up the intervals list into roughly balanced lists:

# %%
! mkdir -p $WORKSPACE_LOCAL/sandbox/scatter
! gatk IntervalListTools \
        --INPUT $TUTORIAL_DATA_PATH/chr20sub.cohort.gc.filtered.interval_list \
        --SUBDIVISION_MODE INTERVAL_COUNT \
        --SCATTER_CONTENT 5000 \
        --OUTPUT $WORKSPACE_LOCAL/sandbox/scatter

# %% [markdown]
# This produces three intervals lists with ~5K intervals each. For the tutorial's 1Kbp bins, this gives ~5Mbp genomic coverage per scatter. Each list is identically named scattered.interval_list within its own folder within the scatter directory. _IntervalListTools_ systematically names the intermediate folders, e.g. temp_0001_of_3, temp_0002_of_3 and temp_0002_of_3.

# %% [markdown]
# ### Comments on select parameters of _IntervalListTools_
#
# - The `--SUBDIVISION_MODE INTERVAL_COUNT` mode scatters intervals into similarly sized lists according to the count of intervals regardless of the base count. The tool intelligently breaks up the chr20sub.cohort.gc.filtered.interval_list's ~15K intervals into lists of 5031, 5031 and 5033 intervals. This is preferable to having a fourth interval list with just 95 intervals.
# - The tool has another useful feature in the context of the gCNV workflow. To subset `-I` binned intervals, provide the regions of interest with `-SI` (`--SECOND_INPUT`) and use the `--ACTION OVERLAPS` mode to create a new intervals list of the overlapping bins. Adding `--SUBDIVISION_MODE INTERVAL_COUNT --SCATTER_CONTENT 5000` will produce scatter intervals concurrently with the subsetting.

# %% [markdown]
# # Call copy number segments and consolidate sample results with _PostprocessGermlineCNVCalls_

# %% [markdown]
# _PostprocessGermlineCNVCalls_ consolidates the scattered _GermlineCNVCaller_ results, performs segmentation and calls copy number states. The tool generates per-interval and per-segment CNV calls in VCF format and runs on a single sample at a time. It also produces consolidated denoised copy-ratio estimates from all interval shards.

# %% [markdown]
# ## _PostprocessGermlineCNVCalls_ in cohort mode
#
# Process a single sample from the 7-sample cohort using the sample index. For `NA19017`, the sample index is 2.

# %%
! gatk PostprocessGermlineCNVCalls \
        --model-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-model \
        --model-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-2of2-model \
        --calls-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-1of2-calls \
        --calls-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort7-twelve/gcnv-cohort7-twelve-2of2-calls \
        --allosomal-contig chrX --allosomal-contig chrY \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort7-calls \
        --sample-index 2 \
        --output-genotyped-intervals $WORKSPACE_LOCAL/sandbox/genotyped-intervals-cohort7-twelve-NA19017.vcf.gz \
        --output-genotyped-segments $WORKSPACE_LOCAL/sandbox/genotyped-segments-cohort7-twelve-NA19017.vcf.gz \
        --output-denoised-copy-ratios $WORKSPACE_LOCAL/sandbox/denoised-copy-ratios-cohort7-twelve-NA19017.tsv \
        --sequence-dictionary $REFERENCE_BUCKET/Homo_sapiens_assembly38.dict

# %% [markdown]
# ## _PostprocessGermlineCNVCalls_ in case mode
#
# `NA19017` is the singular sample with index 0 in the case mode run from section 5.

# %%
! gatk PostprocessGermlineCNVCalls \
        --model-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve/gcnv-cohort6-twelve-1of2-model \
        --model-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-cohort6-twelve/gcnv-cohort6-twelve-2of2-model \
        --calls-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6/gcnv-case-twelve-vs-cohort6-1of2-calls \
        --calls-shard-path $WORKSPACE_LOCAL/sandbox/gcnv-case-twelve-vs-cohort6/gcnv-case-twelve-vs-cohort6-2of2-calls \
        --allosomal-contig chrX --allosomal-contig chrY \
        --contig-ploidy-calls $WORKSPACE_LOCAL/sandbox/ploidy-cohort6-case-calls \
        --sample-index 0 \
        --output-genotyped-intervals $WORKSPACE_LOCAL/sandbox/genotyped-intervals-case-twelve-vs-cohort6.vcf.gz \
        --output-genotyped-segments $WORKSPACE_LOCAL/sandbox/genotyped-segments-case-twelve-vs-cohort6.vcf.gz \
        --output-denoised-copy-ratios $WORKSPACE_LOCAL/sandbox/denoised-copy-ratios-cohort6-twelve-NA19017.tsv \
        --sequence-dictionary $REFERENCE_BUCKET/Homo_sapiens_assembly38.dict

# %% [markdown]
# Each command generates two VCFs with indices, and a TSV file. The `genotyped-intervals` VCF contains variant records for each genomic interval and therefore data covers only the interval regions. For the tutorial's small data, this gives 1400 records. The `genotyped-segments` VCF contains records for each contiguous copy number state segment. For the tutorial's small data, this is 30 and 31 records for cohort and case mode analyses, respectively. Finally, the `denoised-copy-ratios` TSV contains the denoised copy-ratio estimates for each genomic interval.

# %% [markdown]
# The CNV calls for sample `NA19017` are expected to be highly concordant between cohort and case modes. The slight difference is due to the contribution of the sample itself to model training, which is absent in the 23-sample model used for case-calling the sample. Let's take a look.

# %%
# let's exact a few things from the VCF file to a nice table
! gatk VariantsToTable \
        -V $WORKSPACE_LOCAL/sandbox/genotyped-intervals-case-twelve-vs-cohort6.vcf.gz \
        -F CHROM -F POS -F END -GF CN \
        -O $WORKSPACE_LOCAL/sandbox/genotyped-intervals-case-twelve-vs-cohort6.table.txt
! gatk VariantsToTable \
        -V $WORKSPACE_LOCAL/sandbox/genotyped-intervals-cohort7-twelve-NA19017.vcf.gz \
        -F CHROM -F POS -F END -GF CN \
        -O $WORKSPACE_LOCAL/sandbox/genotyped-intervals-cohort7-twelve-NA19017.table.txt

# %%
def load_copy_number_table(table_file_path):
    table_data = []
    with open(table_file_path, 'r') as f:
        for line in f:
            if line.split()[0] == 'CHROM':
                pass
            else:
                line_tokens = line.strip().split()
                start_pos = int(line_tokens[1])
                end_pos = int(line_tokens[2])
                cn = int(line_tokens[3])
                table_data.append((start_pos, end_pos, cn))
    return table_data


cohort_cn_calls_data = load_copy_number_table(
    f'{WORKSPACE_LOCAL}/sandbox/genotyped-intervals-cohort7-twelve-NA19017.table.txt')

case_cn_calls_data = load_copy_number_table(
    f'{WORKSPACE_LOCAL}/sandbox/genotyped-intervals-case-twelve-vs-cohort6.table.txt')

# %%
len(cohort_cn_calls_data)

# %%
len(case_cn_calls_data)

# %%
n_agreeing_intervals = sum(
    cohort_cn_call[2] == case_cn_call[2]
    for cohort_cn_call, case_cn_call in zip(cohort_cn_calls_data, case_cn_calls_data))

print(n_agreeing_intervals)

# %% [markdown]
# Only copy-number calls over 13 intervals differ between cohort and case mode for sample `NA19017`.

# %% [markdown]
# # Where to go from here?

# %% [markdown]
# [Article #11687](https://gatk.zendesk.com/hc/en-us/articles/360035531452) visualizes the results in IGV and provides follow-up discussion.
#
# Towards data exploration, here are two illustrative Jupyter Notebook reports that dissect the results:
# - [Notebook #11685](https://gatk.zendesk.com/hc/en-us/articles/360035890031/) shows an approach to measuring concordance of sample NA19017 gCNV calls to 1000 Genomes Project truth set calls using tutorial chr20sub small data.
# - [Notebook #11686](https://gatk.zendesk.com/hc/en-us/articles/360035889891) examines gCNV callset annotations using larger data, namely chr20 gCNV results from the tutorial's 24-sample cohort.
